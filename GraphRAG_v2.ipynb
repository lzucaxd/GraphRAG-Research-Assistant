# %% [markdown]
# # GraphRAG Implementation with LlamaIndex - V2
#
# [GraphRAG (Graphs + Retrieval Augmented Generation)](https://www.microsoft.com/en-us/research/project/graphrag/) combines the strengths of Retrieval Augmented Generation (RAG) and Query-Focused Summarization (QFS) to effectively handle complex queries over large text datasets. While RAG excels in fetching precise information, it struggles with broader queries that require thematic understanding, a challenge that QFS addresses but cannot scale well. GraphRAG integrates these approaches to offer responsive and thorough querying capabilities across extensive, diverse text corpora.
#
# This notebook provides guidance on constructing the GraphRAG pipeline using the LlamaIndex PropertyGraph abstractions using Neo4J.
#
# This notebook updates the GraphRAG pipeline to v2. If you haven’t checked v1 yet, you can find it [here](https://github.com/run-llama/llama_index/blob/main/docs/docs/examples/cookbooks/GraphRAG_v1.ipynb). Following are the updates to the existing implementation:
#
# 1. Integrate with Neo4J Graph database.
# 2. Embedding based retrieval.

# %% [markdown]
# ## Installation
#
# `graspologic` is used to use hierarchical_leiden for building communities.

# %%
# !pip install llama-index llama-index-graph-stores-neo4j graspologic numpy==1.24.4 scipy==1.12.0 future

# %% [markdown]
# ## Load Data
#
# We will use a sample news article dataset retrieved from Diffbot, which Tomaz has conveniently made available on GitHub for easy access.
#
# The dataset contains 2,500 samples; for ease of experimentation, we will use 50 of these samples, which include the `title` and `text` of news articles.

# %%
import pandas as pd
from llama_index.core import Document

json_path =  "datasets/arxiv_cs_metadata.json"
nrows = 5
papers = pd.read_json(json_path, lines=True, nrows=nrows)
database = "arxivcs-demo"

# papers = pd.read_csv(
#     "https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/news_articles.csv"
# )[:50]

papers.head()
# Out:
#          id              submitter  \
# 0  801.0341       Michael Chertkov
# 1  803.4355     Marko A. Rodriguez
# 2  810.2434          Edward Rosten
# 3  812.4446           Peter Turney
# 4  901.3574  Christoph Benzmueller
#
#                                              authors  \
# 0                      Michael Chertkov (Los Alamos)
# 1                                 Marko A. Rodriguez
# 2           Edward Rosten, Reid Porter, Tom Drummond
# 3  Peter D. Turney (National Research Council of ...
# 4                              Christoph Benzmueller
#
#                                                title  \
# 0  Exactness of Belief Propagation for Some Graph...
# 1  Grammar-Based Random Walkers in Semantic Networks
# 2  Faster and better: a machine learning approach...
# 3  The Latent Relation Mapping Engine: Algorithm ...
# 4  Automating Access Control Logics in Simple Typ...
#
#                                             comments  \
# 0             12 pages, 1 figure, submitted to JSTAT
# 1  First draft of manuscript originally written i...
# 2                               35 pages, 11 figures
# 3  related work available at http://purl.org/pete...
# 4                                      ii + 20 pages
#
#                                          journal-ref  \
# 0                       J. Stat. Mech. (2008) P10016
# 1  Rodriguez, M.A., "Grammar-Based Random Walkers...
# 2              IEEE Trans. PAMI, 32 (2010), 105--119
# 3  Journal of Artificial Intelligence Research, (...
# 4  SEKI Report SR-2008-01 (ISSN 1437-4447), Saarl...
#
#                                 doi               report-no  \
# 0  10.1088/1742-5468/2008/10/P10016      LANL LA-UR-07-8441
# 1      10.1016/j.knosys.2008.03.030           LA-UR-06-7791
# 2            10.1109/TPAMI.2008.275                 07-3912
# 3                 10.1613/jair.2693               NRC-50738
# 4      10.1007/978-3-642-01244-0_34  SEKI Report SR-2008-01
#
#                                           categories  \
# 0  cond-mat.stat-mech cond-mat.other cs.AI cs.IT ...
# 1                                        cs.AI cs.DS
# 2                                        cs.CV cs.LG
# 3                                  cs.CL cs.AI cs.LG
# 4                                        cs.LO cs.AI
#
#                                              license  \
# 0  http://arxiv.org/licenses/nonexclusive-distrib...
# 1  http://creativecommons.org/licenses/publicdomain/
# 2  http://arxiv.org/licenses/nonexclusive-distrib...
# 3  http://arxiv.org/licenses/nonexclusive-distrib...
# 4  http://arxiv.org/licenses/nonexclusive-distrib...
#
#                                             abstract  \
# 0  It is well known that an arbitrary graphical m...
# 1  Semantic networks qualify the meaning of an ed...
# 2  The repeatability and efficiency of a corner d...
# 3  Many AI researchers and cognitive scientists h...
# 4  Garg and Abadi recently proved that prominent ...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Wed, 2 Jan 2008...  2009-11-13
# 1  [{'version': 'v1', 'created': 'Mon, 31 Mar 200...  2008-09-11
# 2  [{'version': 'v1', 'created': 'Tue, 14 Oct 200...  2010-07-09
# 3  [{'version': 'v1', 'created': 'Tue, 23 Dec 200...  2020-08-20
# 4  [{'version': 'v1', 'created': 'Fri, 23 Jan 200...  2015-05-13
#
#                                       authors_parsed
# 0                [[Chertkov, Michael, , Los Alamos]]
# 1                          [[Rodriguez, Marko A., ]]
# 2  [[Rosten, Edward, ], [Porter, Reid, ], [Drummo...
# 3  [[Turney, Peter D., , National Research Counci...
# 4                       [[Benzmueller, Christoph, ]]

# %% [markdown]
# Prepare documents as required by LlamaIndex

# %%
documents = [
    Document(text=f"{row['title']}: {row['abstract']}",)
    for i, row in papers.iterrows()
]

# %% [markdown]
# ## Setup API Key and LLM

# %%
import os


# os.environ["OPENAI_API_KEY"] = "sk-.."

# from llama_index.llms.openai import OpenAI
from llama_index.llms.ollama import Ollama
llm = Ollama(model="qwen2.5",  request_timeout=20000)

# %% [markdown]
# ## GraphRAGExtractor
#
# The GraphRAGExtractor class is designed to extract triples (subject-relation-object) from text and enrich them by adding descriptions for entities and relationships to their properties using an LLM.
#
# This functionality is similar to that of the `SimpleLLMPathExtractor`, but includes additional enhancements to handle entity, relationship descriptions. For guidance on implementation, you may look at similar existing [extractors](https://docs.llamaindex.ai/en/latest/examples/property_graph/Dynamic_KG_Extraction/?h=comparing).
#
# Here's a breakdown of its functionality:
#
# **Key Components:**
#
# 1. `llm:` The language model used for extraction.
# 2. `extract_prompt:` A prompt template used to guide the LLM in extracting information.
# 3. `parse_fn:` A function to parse the LLM's output into structured data.
# 4. `max_paths_per_chunk:` Limits the number of triples extracted per text chunk.
# 5. `num_workers:` For parallel processing of multiple text nodes.
#
#
# **Main Methods:**
#
# 1. `__call__:` The entry point for processing a list of text nodes.
# 2. `acall:` An asynchronous version of __call__ for improved performance.
# 3. `_aextract:` The core method that processes each individual node.
#
#
# **Extraction Process:**
#
# For each input node (chunk of text):
# 1. It sends the text to the LLM along with the extraction prompt.
# 2. The LLM's response is parsed to extract entities, relationships, descriptions for entities and relations.
# 3. Entities are converted into EntityNode objects. Entity description is stored in metadata
# 4. Relationships are converted into Relation objects. Relationship description is stored in metadata.
# 5. These are added to the node's metadata under KG_NODES_KEY and KG_RELATIONS_KEY.
#
# **NOTE:** In the current implementation, we are using only relationship descriptions. In the next implementation, we will utilize entity descriptions during the retrieval stage.

# %%
import asyncio
import nest_asyncio

nest_asyncio.apply()

from typing import Any, List, Callable, Optional, Union, Dict
from IPython.display import Markdown, display

from llama_index.core.async_utils import run_jobs
from llama_index.core.indices.property_graph.utils import (
    default_parse_triplets_fn,
)
from llama_index.core.graph_stores.types import (
    EntityNode,
    KG_NODES_KEY,
    KG_RELATIONS_KEY,
    Relation,
)
from llama_index.core.llms.llm import LLM
from llama_index.core.prompts import PromptTemplate
from llama_index.core.prompts.default_prompts import (
    DEFAULT_KG_TRIPLET_EXTRACT_PROMPT,
)
from llama_index.core.schema import TransformComponent, BaseNode
from llama_index.core.bridge.pydantic import BaseModel, Field


class GraphRAGExtractor(TransformComponent):
    """Extract triples from a graph.

    Uses an LLM and a simple prompt + output parsing to extract paths (i.e. triples) and entity, relation descriptions from text.

    Args:
        llm (LLM):
            The language model to use.
        extract_prompt (Union[str, PromptTemplate]):
            The prompt to use for extracting triples.
        parse_fn (callable):
            A function to parse the output of the language model.
        num_workers (int):
            The number of workers to use for parallel processing.
        max_paths_per_chunk (int):
            The maximum number of paths to extract per chunk.
    """

    llm: LLM
    extract_prompt: PromptTemplate
    parse_fn: Callable
    num_workers: int
    max_paths_per_chunk: int

    def __init__(
        self,
        llm: Optional[LLM] = llm,
        extract_prompt: Optional[Union[str, PromptTemplate]] = None,
        parse_fn: Callable = default_parse_triplets_fn,
        max_paths_per_chunk: int = 10,
        num_workers: int = 4,
    ) -> None:
        """Init params."""
        from llama_index.core import Settings

        if isinstance(extract_prompt, str):
            extract_prompt = PromptTemplate(extract_prompt)

        super().__init__(
            llm=llm or Settings.llm,
            extract_prompt=extract_prompt,
            parse_fn=parse_fn,
            num_workers=num_workers,
            max_paths_per_chunk=max_paths_per_chunk,
        )

    @classmethod
    def class_name(cls) -> str:
        return "GraphExtractor"

    def __call__(
        self, nodes: List[BaseNode], show_progress: bool = False, **kwargs: Any
    ) -> List[BaseNode]:
        """Extract triples from nodes."""
        return asyncio.run(
            self.acall(nodes, show_progress=show_progress, **kwargs)
        )

    async def _aextract(self, node: BaseNode) -> BaseNode:
        """Extract triples from a node."""
        assert hasattr(node, "text")

        text = node.get_content(metadata_mode="llm")
        try:
            llm_response = await self.llm.apredict(
                self.extract_prompt,
                text=text,
                max_knowledge_triplets=self.max_paths_per_chunk,
            )
            print(f"llm_response: {llm_response}")
            entities, entities_relationship = self.parse_fn(llm_response)
        except ValueError:
            entities = []
            entities_relationship = []

        existing_nodes = node.metadata.pop(KG_NODES_KEY, [])
        existing_relations = node.metadata.pop(KG_RELATIONS_KEY, [])
        entity_metadata = node.metadata.copy()
        for entity, entity_type, description in entities:
            entity_metadata["entity_description"] = description
            entity_node = EntityNode(
                name=entity, label=entity_type, properties=entity_metadata
            )
            existing_nodes.append(entity_node)

        relation_metadata = node.metadata.copy()
        for triple in entities_relationship:
            subj, obj, rel, description = triple
            relation_metadata["relationship_description"] = description
            rel_node = Relation(
                label=rel,
                source_id=subj,
                target_id=obj,
                properties=relation_metadata,
            )

            existing_relations.append(rel_node)

        node.metadata[KG_NODES_KEY] = existing_nodes
        node.metadata[KG_RELATIONS_KEY] = existing_relations
        return node

    async def acall(
        self, nodes: List[BaseNode], show_progress: bool = False, **kwargs: Any
    ) -> List[BaseNode]:
        """Extract triples from nodes async."""
        jobs = []
        for node in nodes:
            jobs.append(self._aextract(node))

        return await run_jobs(
            jobs,
            workers=self.num_workers,
            show_progress=show_progress,
            desc="Extracting paths from text",
        )

# %% [markdown]
# ## GraphRAGStore
#
# The `GraphRAGStore` class is an extension of the `Neo4jPropertyGraphStore`class, designed to implement GraphRAG pipeline. Here's a breakdown of its key components and functions:
#
#
# The class uses community detection algorithms to group related nodes in the graph and then it generates summaries for each community using an LLM.
#
#
# **Key Methods:**
#
# `build_communities():`
#
# 1. Converts the internal graph representation to a NetworkX graph.
#
# 2. Applies the hierarchical Leiden algorithm for community detection.
#
# 3. Collects detailed information about each community.
#
# 4. Generates summaries for each community.
#
# `generate_community_summary(text):`
#
# 1. Uses LLM to generate a summary of the relationships in a community.
# 2. The summary includes entity names and a synthesis of relationship descriptions.
#
# `_create_nx_graph():`
#
# 1. Converts the internal graph representation to a NetworkX graph for community detection.
#
# `_collect_community_info(nx_graph, clusters):`
#
# 1. Collects detailed information about each node based on its community.
# 2. Creates a string representation of each relationship within a community.
#
# `_summarize_communities(community_info):`
#
# 1. Generates and stores summaries for each community using LLM.
#
# `get_community_summaries():`
#
# 1. Returns the community summaries by building them if not already done.

# %%
import re
import networkx as nx
from graspologic.partition import hierarchical_leiden
from collections import defaultdict

from llama_index.core.llms import ChatMessage
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore


class GraphRAGStore(Neo4jPropertyGraphStore):
    community_summary = {}
    entity_info = None
    max_cluster_size = 5
    llm = llm

    def generate_community_summary(self, text):
        """Generate summary for a given text using an LLM."""
        messages = [
            ChatMessage(
                role="system",
                content=(
                    "You are provided with a set of relationships from a knowledge graph, each represented as "
                    "(relationship$$$$<source_entity>$$$$<target_entity>$$$$<relation>$$$$<relationship_description>)." 
                    "Your task is to create a summary of these relationships. The summary should include the names of the entities involved and a concise synthesis "
                    "of the relationship descriptions. The goal is to capture the most critical and relevant details that "
                    "highlight the nature and significance of each relationship. Ensure that the summary is coherent and "
                    "integrates the information in a way that emphasizes the key aspects of the relationships."
                ),
            ),
            ChatMessage(role="user", content=text),
        ]
        response = llm.chat(messages)
        clean_response = re.sub(r"^assistant:\s*", "", str(response)).strip()
        return clean_response

    def build_communities(self):
        """Builds communities from the graph and summarizes them."""
        nx_graph = self._create_nx_graph()
        community_hierarchical_clusters = hierarchical_leiden(
            nx_graph, max_cluster_size=self.max_cluster_size
        )
        self.entity_info, community_info = self._collect_community_info(
            nx_graph, community_hierarchical_clusters
        )
        self._summarize_communities(community_info)

    def _create_nx_graph(self):
        """Converts internal graph representation to NetworkX graph."""
        nx_graph = nx.Graph()
        triplets = self.get_triplets()
        for entity1, relation, entity2 in triplets:
            # if relation.properties.get("relationship_description"):

                # relation.properties["relationship_description"] = ""
            relationship_desc = relation.properties.get("relationship_description", "relationship_description_dummy")
            nx_graph.add_node(entity1.name)
            nx_graph.add_node(entity2.name)
            nx_graph.add_edge(
                relation.source_id,
                relation.target_id,
                relationship=relation.label,
                description=relationship_desc,
            )
        return nx_graph

    def _collect_community_info(self, nx_graph, clusters):
        """
        Collect information for each node based on their community,
        allowing entities to belong to multiple clusters.
        """
        entity_info = defaultdict(set)
        community_info = defaultdict(list)

        for item in clusters:
            node = item.node
            cluster_id = item.cluster

            # Update entity_info
            entity_info[node].add(cluster_id)

            for neighbor in nx_graph.neighbors(node):
                edge_data = nx_graph.get_edge_data(node, neighbor)
                if edge_data:
                    detail = f"{node} -> {neighbor} -> {edge_data['relationship']} -> {edge_data['description']}"
                    community_info[cluster_id].append(detail)

        # Convert sets to lists for easier serialization if needed
        entity_info = {k: list(v) for k, v in entity_info.items()}

        return dict(entity_info), dict(community_info)

    def _summarize_communities(self, community_info):
        """Generate and store summaries for each community."""
        for community_id, details in community_info.items():
            details_text = (
                "\n".join(details) + "."
            )  # Ensure it ends with a period
            self.community_summary[
                community_id
            ] = self.generate_community_summary(details_text)

    def get_community_summaries(self):
        """Returns the community summaries, building them if not already done."""
        if not self.community_summary:
            self.build_communities()
        return self.community_summary

# %% [markdown]
# ## GraphRAGQueryEngine
#
# The GraphRAGQueryEngine class is a custom query engine designed to process queries using the GraphRAG approach. It leverages the community summaries generated by the GraphRAGStore to answer user queries. Here's a breakdown of its functionality:
#
# **Main Components:**
#
# `graph_store:` An instance of GraphRAGStore, which contains the community summaries.
# `llm:` A Language Model (LLM) used for generating and aggregating answers.
#
#
# **Key Methods:**
#
# `custom_query(query_str: str)`
#
# 1. This is the main entry point for processing a query. It retrieves community summaries, generates answers from each summary, and then aggregates these answers into a final response.
#
# `generate_answer_from_summary(community_summary, query):`
#
# 1. Generates an answer for the query based on a single community summary.
# Uses the LLM to interpret the community summary in the context of the query.
#
# `aggregate_answers(community_answers):`
#
# 1. Combines individual answers from different communities into a coherent final response.
# 2. Uses the LLM to synthesize multiple perspectives into a single, concise answer.
#
#
# **Query Processing Flow:**
#
# 1. Retrieve community summaries from the graph store.
# 2. For each community summary, generate a specific answer to the query.
# 3. Aggregate all community-specific answers into a final, coherent response.
#
#
# **Example usage:**
#
# ```
# query_engine = GraphRAGQueryEngine(graph_store=graph_store, llm=llm)
#
# response = query_engine.query("query")
# ```

# %%
from llama_index.core.query_engine import CustomQueryEngine
from llama_index.core.llms import LLM
from llama_index.core import PropertyGraphIndex

import re


class GraphRAGQueryEngine(CustomQueryEngine):
    graph_store: GraphRAGStore
    index: PropertyGraphIndex
    llm: LLM = llm
    similarity_top_k: int = 20

    def custom_query(self, query_str: str) -> str:
        """Process all community summaries to generate answers to a specific query."""

        entities = self.get_entities(query_str, self.similarity_top_k)

        community_ids = self.retrieve_entity_communities(
            self.graph_store.entity_info, entities
        )
        community_summaries = self.graph_store.get_community_summaries()
        community_answers = [
            self.generate_answer_from_summary(community_summary, query_str)
            for id, community_summary in community_summaries.items()
            if id in community_ids
        ]

        final_answer = self.aggregate_answers(community_answers)
        return final_answer

    def get_entities(self, query_str, similarity_top_k):
        nodes_retrieved = self.index.as_retriever(
            similarity_top_k=similarity_top_k
        ).retrieve(query_str)

        enitites = set()
        pattern = (
            r"^(\w+(?:\s+\w+)*)\s*->\s*([a-zA-Z\s]+?)\s*->\s*(\w+(?:\s+\w+)*)$"
        )

        for node in nodes_retrieved:
            matches = re.findall(
                pattern, node.text, re.MULTILINE | re.IGNORECASE
            )

            for match in matches:
                subject = match[0]
                obj = match[2]
                enitites.add(subject)
                enitites.add(obj)

        return list(enitites)

    def retrieve_entity_communities(self, entity_info, entities):
        """
        Retrieve cluster information for given entities, allowing for multiple clusters per entity.

        Args:
        entity_info (dict): Dictionary mapping entities to their cluster IDs (list).
        entities (list): List of entity names to retrieve information for.

        Returns:
        List of community or cluster IDs to which an entity belongs.
        """
        community_ids = []

        for entity in entities:
            if entity in entity_info:
                community_ids.extend(entity_info[entity])

        return list(set(community_ids))

    def generate_answer_from_summary(self, community_summary, query):
        """Generate an answer from a community summary based on a given query using LLM."""
        prompt = (
            f"Given the community summary: {community_summary}, "
            f"how would you answer the following query? Query: {query}"
        )
        messages = [
            ChatMessage(role="system", content=prompt),
            ChatMessage(
                role="user",
                content="I need an answer based on the above information.",
            ),
        ]
        response = self.llm.chat(messages)
        cleaned_response = re.sub(r"^assistant:\s*", "", str(response)).strip()
        return cleaned_response

    def aggregate_answers(self, community_answers):
        """Aggregate individual community answers into a final, coherent response."""
        # intermediate_text = " ".join(community_answers)
        prompt = "Combine the following intermediate answers into a final, concise response."
        messages = [
            ChatMessage(role="system", content=prompt),
            ChatMessage(
                role="user",
                content=f"Intermediate answers: {community_answers}",
            ),
        ]
        final_response = self.llm.chat(messages)
        cleaned_final_response = re.sub(
            r"^assistant:\s*", "", str(final_response)
        ).strip()
        return cleaned_final_response

# %% [markdown]
# ##  Build End to End GraphRAG Pipeline
#
# Now that we have defined all the necessary components, let’s construct the GraphRAG pipeline:
#
# 1. Create nodes/chunks from the text.
# 2. Build a PropertyGraphIndex using `GraphRAGExtractor` and `GraphRAGStore`.
# 3. Construct communities and generate a summary for each community using the graph built above.
# 4. Create a `GraphRAGQueryEngine` and begin querying.

# %% [markdown]
# ### Create nodes/ chunks from the text.

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=20,
)
nodes = splitter.get_nodes_from_documents(documents)

# %%
len(nodes)
# Out:
# 5

# %% [markdown]
# ### Build ProperGraphIndex using `GraphRAGExtractor` and `GraphRAGStore`

# %%
KG_TRIPLET_EXTRACT_TMPL = """
-Goal-
Given a text document, identify all entities and their entity types from the text and all relationships among the identified entities.
Given the text, extract up to {max_knowledge_triplets} entity-relation triplets.

-Steps-
1. Identify all entities. For each identified entity, extract the following information:
- entity_name: Name of the entity, capitalized
- entity_type: Type of the entity
- entity_description: Comprehensive description of the entity's attributes and activities
Format each entity as ("entity"$$$$<entity_name>$$$$<entity_type>$$$$<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly related* to each other.
For each pair of related entities, extract the following information:
- source_entity: name of the source entity, as identified in step 1
- target_entity: name of the target entity, as identified in step 1
- relation: relationship between source_entity and target_entity
- relationship_description: explanation as to why you think the source entity and the target entity are related to each other

Format each relationship as ("relationship"$$$$<source_entity>$$$$<target_entity>$$$$<relation>$$$$<relationship_description>)

3. When finished, output.

-Real Data-
######################
text: {text}
######################
output:"""

# %%
entity_pattern = r'\("entity"\$\$\$\$"(.+?)"\$\$\$\$"(.+?)"\$\$\$\$"(.+?)"\)'
relationship_pattern = r'\("relationship"\$\$\$\$"(.+?)"\$\$\$\$"(.+?)"\$\$\$\$"(.+?)"\$\$\$\$"(.+?)"\)'
from llama_index.core.indices.property_graph import DynamicLLMPathExtractor

# def parse_fn(response_str: str) -> Any:
#     entities = re.findall(entity_pattern, response_str)
#     relationships = re.findall(relationship_pattern, response_str)
#     print(f"response_str: {response_str}")
#     print(f"entities: {entities}")
#     print(f"relationships: {relationships}")
#     if entities == []:
#         entities = [("DummyE", "DummyE", "DummyE",)]
#     if relationships == []:
#         relationships = [("DummyR", "DummyR", "DummyR", "DummyR")]
#     return entities, relationships

def parse_fn(response_str: str) -> Any:
    # Updated patterns to match actual output format
    entity_pattern = r'\("entity"\$\$\$\$(.*?)\$\$\$\$(.*?)\$\$\$\$(.*?)\)'
    relationship_pattern = r'\("relationship"\$\$\$\$(.*?)\$\$\$\$(.*?)\$\$\$\$(.*?)\$\$\$\$(.*?)\)'
    
    # Find all matches
    entities = re.findall(entity_pattern, response_str, re.DOTALL)
    relationships = re.findall(relationship_pattern, response_str, re.DOTALL)
    
    # Clean up any whitespace
    entities = [(e1.strip(), e2.strip(), e3.strip()) for e1, e2, e3 in entities]
    relationships = [(r1.strip(), r2.strip(), r3.strip(), r4.strip()) 
                    for r1, r2, r3, r4 in relationships]
    
    # Add default if empty (keeping your original fallback)
    if not entities:
        entities = [("DummyE", "DummyE", "DummyE")]
    if not relationships:
        relationships = [("DummyR", "DummyR", "DummyR", "DummyR")]
    
    print(f"Found entities: {entities}")
    print(f"Found relationships: {relationships}")
    
    return entities, relationships

kg_extractor = GraphRAGExtractor(
    llm=llm,
    extract_prompt=KG_TRIPLET_EXTRACT_TMPL,
    max_paths_per_chunk=20,
    num_workers=4,
    parse_fn=parse_fn,

)
# max_triplets_per_chunk=20,
#         num_workers=4
# kg_extractor = DynamicLLMPathExtractor(
#             llm=llm,
#             max_triplets_per_chunk=20,
#             num_workers=4,
#             allowed_entity_types=None,
#             allowed_relation_types=None,
#             allowed_relation_props=["relationship_description"],
#             allowed_entity_props=[],
#             parse_fn=parse_fn,
#             extract_prompt=KG_TRIPLET_EXTRACT_TMPL,
# )

# %% [markdown]
# ## Docker Setup And Neo4J setup
#
# To launch Neo4j locally, first ensure you have docker installed. Then, you can launch the database with the following docker command.
#
# ```
# docker run \
#     -p 7474:7474 -p 7687:7687 \
#     -v $PWD/data:/data -v $PWD/plugins:/plugins \
#     --name neo4j-apoc \
#     -e NEO4J_apoc_export_file_enabled=true \
#     -e NEO4J_apoc_import_file_enabled=true \
#     -e NEO4J_apoc_import_file_use__neo4j__config=true \
#     -e NEO4JLABS_PLUGINS=\[\"apoc\"\] \
#     neo4j:latest
# ```
# From here, you can open the db at http://localhost:7474/. On this page, you will be asked to sign in. Use the default username/password of neo4j and neo4j.
#
# Once you login for the first time, you will be asked to change the password.

# %%
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore

# Note: used to be `Neo4jPGStore`
graph_store = GraphRAGStore(
    username="neo4j", password="password", url="bolt://localhost:7687", database=database
)

# %%
from llama_index.core import PropertyGraphIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# embed_model = HuggingFaceEmbedding("sentence-transformers/all-MiniLM-L6-v2")
embed_model = HuggingFaceEmbedding("avsolatorio/GIST-all-MiniLM-L6-v2")
# GIST-all-MiniLM-L6-v2 
# PropertyGraphIndex.from_documents(
#             documents,
#             property_graph_store=graph_store,
#             llm=self.llm,
#             embed_model=self.embed_model,
#             embed_kg_nodes=True,
#             kg_extractors=[self.kg_extractor],
#             show_progress=True
# )

index = PropertyGraphIndex(
    nodes=nodes,
    kg_extractors=[kg_extractor],
    property_graph_store=graph_store,
    llm=llm,
    show_progress=True,
    embed_model=embed_model,
)
# Out:
# Extracting paths from text:  20%|██        | 1/5 [00:49<03:16, 49.21s/it]
# llm_response: ### Entities Identification
#
# 1. ("entity"$$$$Latent Relation Mapping Engine$$$$Algorithm$$$$An algorithm designed to map analogical relations between lists of words using a large corpus of raw text.")
# 2. ("entity"$$$$Structure Mapping Theory (SMT)$$$$Theory$$$$A theory on computational modeling of analogy-making, which involves mapping structures between two domains.")
# 3. ("entity"$$$$Structure Mapping Engine (SME)$$$$Engine$$$$An implementation of Structure Mapping Theory used to create analogical mappings but requires complex hand-coded representations.")
# 4. ("entity"$$$$Latent Relational Analysis (LRA)$$$$Analysis Technique$$$$A method for discovering semantic relations among words without the need for hand-coded representations, combined with SME in LRME.")
# 5. ("entity"$$$$Analogical Mapping Problems$$$$Problem Set$$$$A set of problems used to evaluate the performance of different analogy-making algorithms, consisting of ten scientific analogies and ten common metaphors based ones.")
# 6. ("entity"$$$$Performance$$$$(Attribute)$$$$Measure of how well an algorithm or system performs in a specific task.)
#
# ### Entity Relationships
#
# 1. ("relationship"$$$$Latent Relation Mapping Engine (LRME)$$$$Structure Mapping Theory (SMT)$$$$Influenced By$$$$The LRME builds on the concept of structure mapping, aiming to improve upon SME by removing the need for hand-coded representations.")
# 2. ("relationship"$$$$Latent Relation Mapping Engine (LRME)$$$$Structure Mapping Engine (SME)$$$$Inspired From$$$$The LRME is inspired by the Structure Mapping Engine but improves its limitations in requiring complex hand-coded representations.")
# 3. ("relationship"$$$$Latent Relation Mapping Engine (LRME)$$$$Latent Relational Analysis (LRA)$$$$Combined With$$$$Both LRA and SME ideas are combined to create the LRME, aiming to discover semantic relations automatically without manual coding.")
# 4. ("relationship"$$$$Analogical Mapping Problems$$$$Latent Relation Mapping Engine (LRME)$$$$Evaluated By$$$$The LRME is evaluated on a set of analogical mapping problems designed to test its performance against other methods.")
# 5. ("relationship"$$$$Performance$$$$Latent Relation Mapping Engine (LRME)$$$$Measured By$$$$The performance of the LRME is measured using the set of analogical mapping problems, showing human-level accuracy.)
#
# This output provides an overview of key entities and their relationships based on the provided text.
# Found entities: [('Latent Relation Mapping Engine', 'Algorithm', 'An algorithm designed to map analogical relations between lists of words using a large corpus of raw text."'), ('Structure Mapping Theory (SMT)', 'Theory', 'A theory on computational modeling of analogy-making, which involves mapping structures between two domains."'), ('Structure Mapping Engine (SME)', 'Engine', 'An implementation of Structure Mapping Theory used to create analogical mappings but requires complex hand-coded representations."'), ('Latent Relational Analysis (LRA)', 'Analysis Technique', 'A method for discovering semantic relations among words without the need for hand-coded representations, combined with SME in LRME."'), ('Analogical Mapping Problems', 'Problem Set', 'A set of problems used to evaluate the performance of different analogy-making algorithms, consisting of ten scientific analogies and ten common metaphors based ones."'), ('Performance', '(Attribute)', 'Measure of how well an algorithm or system performs in a specific task.')]
# Found relationships: [('Latent Relation Mapping Engine (LRME)', 'Structure Mapping Theory (SMT)', 'Influenced By', 'The LRME builds on the concept of structure mapping, aiming to improve upon SME by removing the need for hand-coded representations."'), ('Latent Relation Mapping Engine (LRME)', 'Structure Mapping Engine (SME)', 'Inspired From', 'The LRME is inspired by the Structure Mapping Engine but improves its limitations in requiring complex hand-coded representations."'), ('Latent Relation Mapping Engine (LRME)', 'Latent Relational Analysis (LRA)', 'Combined With', 'Both LRA and SME ideas are combined to create the LRME, aiming to discover semantic relations automatically without manual coding."'), ('Analogical Mapping Problems', 'Latent Relation Mapping Engine (LRME)', 'Evaluated By', 'The LRME is evaluated on a set of analogical mapping problems designed to test its performance against other methods."'), ('Performance', 'Latent Relation Mapping Engine (LRME)', 'Measured By', 'The performance of the LRME is measured using the set of analogical mapping problems, showing human-level accuracy.')]
# Extracting paths from text:  40%|████      | 2/5 [00:50<01:03, 21.31s/it]
# llm_response: ```plaintext
# # Entities
#
# ("entity"$$$$Feature Detector$$$$Detector$$$$A software component designed to identify specific features within an image or video stream. This entity is discussed in the context of corner detection and its performance metrics include repeatability and efficiency.)
#
# ("entity"$$$$Harris Detector$$$$Detector$$$$An older feature detector, used as a baseline for comparison with other detectors such as SIFT. It is noted that this detector does not operate at frame rate when compared to others.)
#
# ("entity"$$$$SIFT (Scale-Invariant Feature Transform)$$$$Detector$$$$A well-known method for detecting and describing local features in images or videos. It operates slower than the machine learning-based feature detector described in the text, as evidenced by its higher processing time requirement.)
#
# ("entity"$$$$Machine Learning Approach$$$$Method$$$$A new technique discussed in the paper that utilizes machine learning to derive a feature detector capable of operating at frame rate for live video processing.)
#
# ("entity"$$$$Live PAL Video$$$$Input Data$$$$Video data with a specific format (PAL) used as input to the feature detection algorithm. It is mentioned that this type of video can be fully processed by the new detector in less than 5% of available processing time.)
#
# ("entity"$$$$3D Scene Comparison$$$$Test Scenario$$$$A set of tests applied to corner detectors based on their repeatability, specifically with respect to 3D scenes. The results indicate significant performance differences among different detectors under this criterion.)
#
# # Relationships
#
# ("relationship"$$$$Feature Detector$$$$Machine Learning Approach$$$$Created$$$$The new feature detector was derived using machine learning techniques as described in the paper.)
#
# ("relationship"$$$$Feature Detector$$$$Live PAL Video$$$$Input Output Relation$$$$The new feature detector can fully process live PAL video in less than 5% of available processing time, demonstrating its efficiency.)
#
# ("relationship"$$$$Machine Learning Approach$$$$Harris Detector$$$$Comparison$$$$The machine learning approach resulted in a faster and more efficient feature detection method compared to the Harris detector, which could not operate at frame rate under similar conditions.)
#
# ("relationship"$$$$Machine Learning Approach$$$$SIFT$$$$Comparison$$$$The machine learning-based feature detector significantly outperformed SIFT on stringent tests based on repeatability criterion applied to 3D scenes.)
#
# ("relationship"$$$$Harris Detector$$$$SIFT$$$$Baseline Comparison$$$$Both detectors are used as baselines for comparison, highlighting their performance metrics in relation to the new machine learning approach.)
# ```
#
# This output provides a structured representation of identified entities and relationships within the given text.
# Found entities: [('Feature Detector', 'Detector', 'A software component designed to identify specific features within an image or video stream. This entity is discussed in the context of corner detection and its performance metrics include repeatability and efficiency.'), ('Harris Detector', 'Detector', 'An older feature detector, used as a baseline for comparison with other detectors such as SIFT. It is noted that this detector does not operate at frame rate when compared to others.'), ('SIFT (Scale-Invariant Feature Transform)', 'Detector', 'A well-known method for detecting and describing local features in images or videos. It operates slower than the machine learning-based feature detector described in the text, as evidenced by its higher processing time requirement.'), ('Machine Learning Approach', 'Method', 'A new technique discussed in the paper that utilizes machine learning to derive a feature detector capable of operating at frame rate for live video processing.'), ('Live PAL Video', 'Input Data', 'Video data with a specific format (PAL'), ('3D Scene Comparison', 'Test Scenario', 'A set of tests applied to corner detectors based on their repeatability, specifically with respect to 3D scenes. The results indicate significant performance differences among different detectors under this criterion.')]
# Found relationships: [('Feature Detector', 'Machine Learning Approach', 'Created', 'The new feature detector was derived using machine learning techniques as described in the paper.'), ('Feature Detector', 'Live PAL Video', 'Input Output Relation', 'The new feature detector can fully process live PAL video in less than 5% of available processing time, demonstrating its efficiency.'), ('Machine Learning Approach', 'Harris Detector', 'Comparison', 'The machine learning approach resulted in a faster and more efficient feature detection method compared to the Harris detector, which could not operate at frame rate under similar conditions.'), ('Machine Learning Approach', 'SIFT', 'Comparison', 'The machine learning-based feature detector significantly outperformed SIFT on stringent tests based on repeatability criterion applied to 3D scenes.'), ('Harris Detector', 'SIFT', 'Baseline Comparison', 'Both detectors are used as baselines for comparison, highlighting their performance metrics in relation to the new machine learning approach.')]
# Extracting paths from text:  60%|██████    | 3/5 [02:01<01:27, 43.59s/it]
# llm_response: Let's break down the text to identify entities, their types, descriptions, relationships, and relevant triplets.
#
# ### Step 1: Identifying Entities
#
# #### Entity 1:
# - **entity_name**: Graphical Model
# - **entity_type**: Concept/Model
# - **entity_description**: A model used in statistical inference defined on a graph. It can be either tree-like (without loops) or loopy (with loops). In the zero-temperature limit, it is considered for finding the global minimum using Belief Propagation and Linear Programming.
#
# #### Entity 2:
# - **entity_name**: Iterative Belief Propagation (BP)
# - **entity_type**: Algorithm
# - **entity_description**: An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.
#
# #### Entity 3:
# - **entity_name**: Bethe Free Energy Functional
# - **entity_type**: Concept/Function
# - **entity_description**: A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.
#
# #### Entity 4:
# - **entity_name**: Maximum-Likelihood (ML) Solution
# - **entity_type**: Solution
# - **entity_description**: The optimal solution obtained in the zero-temperature limit that maximizes likelihood. It is not guaranteed to be found by BP for loopy graphs but can be found using Linear Programming.
#
# #### Entity 5:
# - **entity_name**: Linear Programming (LP)
# - **entity_type**: Algorithm
# - **entity_description**: A method used to find the global minimum of a function subject to constraints, specifically applicable in finding ML solutions and equivalent to certain forms of graphical models in the zero-temperature limit.
#
# #### Entity 6:
# - **entity_name**: Totally-Uni-Modular (TUM) Matrix
# - **entity_type**: Constraint
# - **entity_description**: A type of matrix used in LP that ensures its solution is integral. It plays a key role in certain special graphical models where ML solutions can be found using efficient algorithms.
#
# ### Step 2: Identifying Relationships
#
# #### Relationship 1:
# - **source_entity**: Graphical Model
# - **target_entity**: Iterative Belief Propagation (BP)
# - **relation**: Solved by
# - **relationship_description**: The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.
#
# #### Relationship 2:
# - **source_entity**: Graphical Model
# - **target_entity**: Bethe Free Energy Functional
# - **relation**: Minimized by
# - **relationship_description**: In the context of tree-like graphs, the Bethe free energy functional is minimized by iterative BP algorithms.
#
# #### Relationship 3:
# - **source_entity**: Iterative Belief Propagation (BP)
# - **target_entity**: Bethe Free Energy Functional
# - **relation**: Converges to minimum of
# - **relationship_description**: For loopy graphical models, the iterative BP algorithm may converge to one of multiple minima or not converge at all.
#
# #### Relationship 4:
# - **source_entity**: Graphical Model
# - **target_entity**: Maximum-Likelihood (ML) Solution
# - **relation**: ML solution is found by
# - **relationship_description**: In special cases, the ML solutions can be found using efficient algorithms like Linear Programming for certain graphical models with loops.
#
# #### Relationship 5:
# - **source_entity**: Linear Programming (LP)
# - **target_entity**: Graphical Model
# - **relation**: Reducible to in zero-temperature limit
# - **relationship_description**: A class of graphical models is reducible in the zero-temperature limit to LP with TUM constraints.
#
# #### Relationship 6:
# - **source_entity**: Linear Programming (LP)
# - **target_entity**: Bethe-Free Energy Minimization
# - **relation**: Equivalent to gapless relaxation of
# - **relationship_description**: The gapless LP relaxation of a graphical model in the zero-temperature limit is equivalent to the respective version of the Bethe-free energy minimization.
#
# ### Step 3: Output
#
# ```plaintext
# ("entity"$$$$Graphical Model$$$$Concept/Model$$$$A model used in statistical inference defined on a graph. It can be either tree-like (without loops) or loopy (with loops). In the zero-temperature limit, it is considered for finding the global minimum using Belief Propagation and Linear Programming.)
# ("entity"$$$$Iterative Belief Propagation (BP)$$$$Algorithm$$$$An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.)
# ("entity"$$$$Bethe Free Energy Functional$$$$Concept/Function$$$$A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.)
# ("entity"$$$$Maximum-Likelihood (ML) Solution$$$$Solution$$$$The optimal solution obtained in the zero-temperature limit that maximizes likelihood. It is not guaranteed to be found by BP for loopy graphs but can be found using Linear Programming.)
# ("entity"$$$$Linear Programming (LP)$$$$Algorithm$$$$A method used to find the global minimum of a function subject to constraints, specifically applicable in finding ML solutions and equivalent to certain forms of graphical models in the zero-temperature limit.)
# ("entity"$$$$Totally-Uni-Modular (TUM) Matrix$$$$Constraint$$$$A type of matrix used in LP that ensures its solution is integral. It plays a key role in certain special graphical models where ML solutions can be found using efficient algorithms.)
# ("relationship"$$$$Graphical Model$$$$Iterative Belief Propagation (BP)$$$$Solved by$$$$The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.)
# ("relationship"$$$$Graphical Model$$$$Bethe Free Energy Functional$$$$Minimized by$$$$In the context of tree-like graphs, the Bethe free energy functional is minimized by iterative BP algorithms.)
# ("relationship"$$$$Iterative Belief Propagation (BP)$$$$Bethe Free Energy Functional$$$$Converges to minimum of$$$$For loopy graphical models, the iterative BP algorithm may converge to one of multiple minima or not converge at all.)
# ("relationship"$$$$Graphical Model$$$$Maximum-Likelihood (ML) Solution$$$$ML solution is found by$$$$In special cases, the ML solutions can be found using efficient algorithms like Linear Programming for certain graphical models with loops.)
# ("relationship"$$$$Linear Programming (LP)$$$$Graphical Model$$$$Reducible to in zero-temperature limit$$$$A class of graphical models is reducible in the zero-temperature limit to LP with TUM constraints.)
# ("relationship"$$$$Linear Programming (LP)$$$$Bethe-Free Energy Minimization$$$$Equivalent to gapless relaxation of$$$$The gapless LP relaxation of a graphical model in the zero-temperature limit is equivalent to the respective version of the Bethe-free energy minimization.)
# ```
#
# This output provides the identified entities and their relationships based on the given text.
# Found entities: [('Graphical Model', 'Concept/Model', 'A model used in statistical inference defined on a graph. It can be either tree-like (without loops'), ('Iterative Belief Propagation (BP)', 'Algorithm', 'An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.'), ('Bethe Free Energy Functional', 'Concept/Function', 'A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.'), ('Maximum-Likelihood (ML) Solution', 'Solution', 'The optimal solution obtained in the zero-temperature limit that maximizes likelihood. It is not guaranteed to be found by BP for loopy graphs but can be found using Linear Programming.'), ('Linear Programming (LP)', 'Algorithm', 'A method used to find the global minimum of a function subject to constraints, specifically applicable in finding ML solutions and equivalent to certain forms of graphical models in the zero-temperature limit.'), ('Totally-Uni-Modular (TUM) Matrix', 'Constraint', 'A type of matrix used in LP that ensures its solution is integral. It plays a key role in certain special graphical models where ML solutions can be found using efficient algorithms.')]
# Found relationships: [('Graphical Model', 'Iterative Belief Propagation (BP)', 'Solved by', 'The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.'), ('Graphical Model', 'Bethe Free Energy Functional', 'Minimized by', 'In the context of tree-like graphs, the Bethe free energy functional is minimized by iterative BP algorithms.'), ('Iterative Belief Propagation (BP)', 'Bethe Free Energy Functional', 'Converges to minimum of', 'For loopy graphical models, the iterative BP algorithm may converge to one of multiple minima or not converge at all.'), ('Graphical Model', 'Maximum-Likelihood (ML) Solution', 'ML solution is found by', 'In special cases, the ML solutions can be found using efficient algorithms like Linear Programming for certain graphical models with loops.'), ('Linear Programming (LP)', 'Graphical Model', 'Reducible to in zero-temperature limit', 'A class of graphical models is reducible in the zero-temperature limit to LP with TUM constraints.'), ('Linear Programming (LP)', 'Bethe-Free Energy Minimization', 'Equivalent to gapless relaxation of', 'The gapless LP relaxation of a graphical model in the zero-temperature limit is equivalent to the respective version of the Bethe-free energy minimization.')]
# Extracting paths from text:  80%|████████  | 4/5 [02:16<00:32, 32.52s/it]
# llm_response: ### Step 1: Identify All Entities and Their Types
#
# 1. **entity**$$$$Grammar-Based Random Walkers$$$$Process$$$$A model for navigating semantic networks using a grammar-based approach.**
# 2. **entity**$$$$Semantic Networks$$$$Concept$$$$Collections of vertices (nodes) connected by edges, representing relationships between concepts or entities.**
# 3. **entity**$$$$Vertices$$$$Node$$$$Individual points in the network that represent concepts or entities.**
# 4. **entity**$$$$Edges$$$$Relationship$$$$Lines connecting vertices to represent relationships between them.**
# 5. **entity**$$$$Central Vertex$$$$Node$$$$Nodes considered important within a semantic network due to their centrality measures.**
# 6. **entity**$$$$Context-Based Rankings$$$$Method$$$$Ranks nodes based on user-defined contexts or criteria, often used in metrics for semantic networks.**
# 7. **entity**$$$$Semantic Network Metrics$$$$Framework$$$$Tools and methods for quantifying the importance of vertices in a semantic network.**
# 8. **entity**$$$$Directed Paths$$$$Path$$$$Sequential traversals from one vertex to another in a semantic network.**
# 9. **entity**$$$$Eigenvector Centrality$$$$Metric$$$$A measure of the influence of nodes, where nodes are important if they are connected to other important nodes.**
# 10. **entity**$$$$PageRank$$$$Metric$$$$Algorithm for determining the relative importance (or centrality) of vertices in a network.**
# 11. **entity**$$$$Random Walker Model$$$$Process$$$$A method for traversing semantic networks probabilistically, constrained by a user-defined grammar.**
# 12. **entity**$$$$Markov Chain Analysis$$$$Framework$$$$Mathematical model used to describe the behavior of systems that change states over time in a random manner.**
# 13. **entity**$$$$Grammar$$$$Data Structure$$$$A user-defined structure that defines rules for navigating vertices within semantic networks, influencing ranking outcomes.**
# 14. **entity**$$$$Resource Description Framework (RDF)$$$$Standard$$$$A standard for representing data on the web, often used in the Semantic Web initiative.**
#
# ### Step 2: Identify Relationships Among Entities
#
# 1. **relationship**$$$$Grammar-Based Random Walkers$$$$Semantic Networks$$$$Process$$$: The grammar-based random walkers model is applied to navigate semantic networks.
# 2. **relationship**$$$$Vertices$$$$Edges$$$$Component$$$: Vertices and edges are fundamental components of semantic networks, with vertices being connected by edges to represent relationships.
# 3. **relationship**$$$$Central Vertex$$$$Vertices$$$$Attribute$$$: Central vertices are nodes in a semantic network that are deemed important due to their centrality measures.
# 4. **relationship**$$$$Context-Based Rankings$$$$Semantic Network Metrics$$$$Method$$$: Context-based rankings are methods used within the framework of semantic network metrics for ranking vertices based on user-defined contexts.
# 5. **relationship**$$$$Directed Paths$$$$Vertices$$$$Path$$$: Directed paths between two vertices represent specific sequential traversals in a semantic network.
# 6. **relationship**$$$$Eigenvector Centrality$$$$Random Walker Model$$$$Metric$$$: Eigenvector centrality is calculated using the random walker model, reflecting the influence of nodes based on their connections to other important nodes.
# 7. **relationship**$$$$PageRank$$$$Random Walker Model$$$$Metric$$$: PageRank is another metric used in the random walker model for determining the relative importance of vertices in a network.
# 8. **relationship**$$$$Random Walker Model$$$$Grammar$$$$Process$$$: The random walker model employs a grammar to constrain the traversal and ranking process within semantic networks.
# 9. **relationship**$$$$Resource Description Framework (RDF)$$$$Semantic Networks$$$$Standard$$$: RDF is used as a standard for representing data in semantic networks, fitting into the framework of the Semantic Web initiative.
#
# ### Output:
#
# ```plaintext
# (entity Grammar-Based Random Walkers $$$$
# Entity Name: Grammar-Based Random Walkers
# Entity Type: Process
# Entity Description: A model for navigating semantic networks using a grammar-based approach.)
#
# (entity Semantic Networks $$$$
# Entity Name: Semantic Networks
# Entity Type: Concept
# Entity Description: Collections of vertices (nodes) connected by edges, representing relationships between concepts or entities.)
#
# (entity Vertices $$$$
# Entity Name: Vertices
# Entity Type: Node
# Entity Description: Individual points in the network that represent concepts or entities.)
#
# (entity Edges $$$$
# Entity Name: Edges
# Entity Type: Relationship
# Entity Description: Lines connecting vertices to represent relationships between them.)
#
# (entity Central Vertex $$$$
# Entity Name: Central Vertex
# Entity Type: Node
# Entity Description: Nodes considered important within a semantic network due to their centrality measures.)
#
# (entity Context-Based Rankings $$$$
# Entity Name: Context-Based Rankings
# Entity Type: Method
# Entity Description: Ranks nodes based on user-defined contexts or criteria, often used in metrics for semantic networks.)
#
# (entity Semantic Network Metrics $$$$
# Entity Name: Semantic Network Metrics
# Entity Type: Framework
# Entity Description: Tools and methods for quantifying the importance of vertices in a semantic network.)
#
# (entity Directed Paths $$$$
# Entity Name: Directed Paths
# Entity Type: Path
# Entity Description: Sequential traversals from one vertex to another in a semantic network.)
#
# (entity Eigenvector Centrality $$$$
# Entity Name: Eigenvector Centrality
# Entity Type: Metric
# Entity Description: A measure of the influence of nodes, where nodes are important if they are connected to other important nodes.)
#
# (entity PageRank $$$$
# Entity Name: PageRank
# Entity Type: Metric
# Entity Description: Algorithm for determining the relative importance (or centrality) of vertices in a network.)
#
# (entity Random Walker Model $$$$
# Entity Name: Random Walker Model
# Entity Type: Process
# Entity Description: A method for traversing semantic networks probabilistically, constrained by a user-defined grammar.)
#
# (entity Markov Chain Analysis $$$$
# Entity Name: Markov Chain Analysis
# Entity Type: Framework
# Entity Description: Mathematical model used to describe the behavior of systems that change states over time in a random manner.)
#
# (entity Grammar $$$$
# Entity Name: Grammar
# Entity Type: Data Structure
# Entity Description: A user-defined structure that defines rules for navigating vertices within semantic networks, influencing ranking outcomes.)
#
# (entity Resource Description Framework (RDF) $$$$
# Entity Name: Resource Description Framework (RDF)
# Entity Type: Standard
# Entity Description: A standard for representing data on the web, often used in the Semantic Web initiative.)
#
# (relationship Grammar-Based Random Walkers $$$$
# Source Entity: Grammar-Based Random Walkers
# Target Entity: Semantic Networks
# Relation: Process
# Relationship Description: The grammar-based random walkers model is applied to navigate semantic networks.
#
# (relationship Vertices $$$$
# Source Entity: Vertices
# Target Entity: Edges
# Relation: Component
# Relationship Description: Vertices and edges are fundamental components of semantic networks, with vertices being connected by edges to represent relationships between them.
#
# (relationship Central Vertex $$$$
# Source Entity: Central Vertex
# Target Entity: Vertices
# Relation: Attribute
# Relationship Description: Central vertices are nodes in a semantic network that are deemed important due to their centrality measures.
#
# (relationship Context-Based Rankings $$$$
# Source Entity: Context-Based Rankings
# Target Entity: Semantic Network Metrics
# Relation: Method
# Relationship Description: Context-based rankings are methods used within the framework of semantic network metrics for ranking vertices based on user-defined contexts.
#
# (relationship Directed Paths $$$$
# Source Entity: Directed Paths
# Target Entity: Vertices
# Relation: Path
# Relationship Description: Directed paths between two vertices represent specific sequential traversals in a semantic network.
#
# (relationship Eigenvector Centrality $$$$
# Source Entity: Eigenvector Centrality
# Target Entity: Random Walker Model
# Relation: Metric
# Relationship Description: Eigenvector centrality is calculated using the random walker model, reflecting the influence of nodes based on their connections to other important nodes.
#
# (relationship PageRank $$$$
# Source Entity: PageRank
# Target Entity: Random Walker Model
# Relation: Metric
# Relationship Description: PageRank is another metric used in the random walker model for determining the relative importance of vertices in a network.
#
# (relationship Random Walker Model $$$$
# Source Entity: Random Walker Model
# Target Entity: Grammar
# Relation: Process
# Relationship Description: The random walker model employs a grammar to constrain the traversal and ranking process within semantic networks.
#
# (relationship Resource Description Framework (RDF) $$$$
# Source Entity: Resource Description Framework (RDF)
# Target Entity: Semantic Networks
# Relation: Standard
# Relationship Description: RDF is used as a standard for representing data in semantic networks, fitting into the framework of the Semantic Web initiative.
# ```
# Found entities: [('DummyE', 'DummyE', 'DummyE')]
# Found relationships: [('DummyR', 'DummyR', 'DummyR', 'DummyR')]
# Extracting paths from text: 100%|██████████| 5/5 [02:24<00:00, 28.98s/it]
# llm_response: ### Step 1: Identify all entities
#
# #### Entity 1:
# - **entity_name**: Automating Access Control Logics
# - **entity_type**: Process/Task
# - **entity_description**: The process of translating and embedding access control logics into simple type theory using a theorem prover.
#
# ("entity"$$$$Automating Access Control Logics$$$$Process/Task$$$$The process of translating and embedding access control logics into simple type theory using a theorem prover.)
#
# #### Entity 2:
# - **entity_name**: LEO-II
# - **entity_type**: Tool/Software
# - **entity_description**: A higher-order automated theorem prover used for reasoning in and about normal multimodal and monomodal logics.
#
# ("entity"$$$$LEO-II$$$$Tool/Software$$$$A higher-order automated theorem prover used for reasoning in and about normal multimodal and monomodal logics.)
#
# #### Entity 3:
# - **entity_name**: Simple Type Theory
# - **entity_type**: Formal System
# - **entity_description**: A formal system that includes simple type theory, also known as higher-order logic.
#
# ("entity"$$$$Simple Type Theory$$$$Formal System$$$$A formal system that includes simple type theory, also known as higher-order logic.)
#
# #### Entity 4:
# - **entity_name**: Modal Logic S4
# - **entity_type**: Formal System
# - **entity_description**: A normal modal logic system used for the translation of access control logics.
#
# ("entity"$$$$Modal Logic S4$$$$Formal System$$$$A normal modal logic system used for the translation of access control logics.)
#
# #### Entity 5:
# - **entity_name**: Garg and Abadi
# - **entity_type**: Researchers/Experts
# - **entity_description**: The researchers who proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.
#
# ("entity"$$$$Garg and Abadi$$$$Researchers/Experts$$$$The researchers who proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.)
#
# #### Entity 6:
# - **entity_name**: Normal Multimodal Logics
# - **entity_type**: Formal System
# - **entity_description**: A collection of multimodal logics, including monomodal systems K and S4.
#
# ("entity"$$$$Normal Multimodal Logics$$$$Formal System$$$$A collection of multimodal logics, including monomodal systems K and S4.)
#
# ### Step 2: Identify relationships
#
# #### Relationship 1:
# - **source_entity**: Automating Access Control Logics
# - **target_entity**: LEO-II
# - **relation**: Utilized by
# - **relationship_description**: The process of automating access control logics is utilizing the theorem prover LEO-II.
#
# ("relationship"$$$$Automating Access Control Logics$$$$LEO-II$$$$Utilized by$$$$The process of automating access control logics is utilizing the theorem prover LEO-II.)
#
# #### Relationship 2:
# - **source_entity**: Automating Access Control Logics
# - **target_entity**: Simple Type Theory
# - **relation**: Embedded in
# - **relationship_description**: The process of automating access control logics involves embedding different access control logics into simple type theory.
#
# ("relationship"$$$$Automating Access Control Logics$$$$Simple Type Theory$$$$Embedded in$$$$The process of automating access control logics involves embedding different access control logics into simple type theory.)
#
# #### Relationship 3:
# - **source_entity**: LEO-II
# - **target_entity**: Modal Logic S4
# - **relation**: Can automate reasoning about
# - **relationship_description**: The theorem prover LEO-II can be applied to automate reasoning in modal logic S4.
#
# ("relationship"$$$$LEO-II$$$$Modal Logic S4$$$$Can automate reasoning about$$$$The theorem prover LEO-II can be applied to automate reasoning in modal logic S4.)
#
# #### Relationship 4:
# - **source_entity**: Garg and Abadi
# - **target_entity**: Modal Logic S4
# - **relation**: Proved sound and complete translation into
# - **relationship_description**: The researchers Garg and Abadi proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.
#
# ("relationship"$$$$Garg and Abadi$$$$Modal Logic S4$$$$Proved sound and complete translation into$$$$The researchers Garg and Abadi proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.)
#
# #### Relationship 5:
# - **source_entity**: Normal Multimodal Logics
# - **target_entity**: Simple Type Theory
# - **relation**: Embedded in
# - **relationship_description**: Normal multimodal logics, including monomodal systems K and S4, can be embedded in simple type theory.
#
# ("relationship"$$$$Normal Multimodal Logics$$$$Simple Type Theory$$$$Embedded in$$$$Normal multimodal logics, including monomodal systems K and S4, can be embedded in simple type theory.)
#
# ### Output:
#
# ```
# (entity)$$$$Automating Access Control Logics$$$$Process/Task$$$$The process of translating and embedding access control logics into simple type theory using a theorem prover.
# (entity)$$$$LEO-II$$$$Tool/Software$$$$A higher-order automated theorem prover used for reasoning in and about normal multimodal and monomodal logics.
# (entity)$$$$Simple Type Theory$$$$Formal System$$$$A formal system that includes simple type theory, also known as higher-order logic.
# (entity)$$$$Modal Logic S4$$$$Formal System$$$$A normal modal logic system used for the translation of access control logics.
# (entity)$$$$Garg and Abadi$$$$Researchers/Experts$$$$The researchers who proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.
# (entity)$$$$Normal Multimodal Logics$$$$Formal System$$$$A collection of multimodal logics, including monomodal systems K and S4.
#
# (relationship)$$$$Automating Access Control Logics$$$$LEO-II$$$$Utilized by$$$$The process of automating access control logics is utilizing the theorem prover LEO-II.
# (relationship)$$$$Automating Access Control Logics$$$$Simple Type Theory$$$$Embedded in$$$$The process of automating access control logics involves embedding different access control logics into simple type theory.
# (relationship)$$$$LEO-II$$$$Modal Logic S4$$$$Can automate reasoning about$$$$The theorem prover LEO-II can be applied to automate reasoning in modal logic S4.
# (relationship)$$$$Garg and Abadi$$$$Modal Logic S4$$$$Proved sound and complete translation into$$$$The researchers Garg and Abadi proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.
# (relationship)$$$$Normal Multimodal Logics$$$$Simple Type Theory$$$$Embedded in$$$$Normal multimodal logics, including monomodal systems K and S4, can be embedded in simple type theory.
# ```
# Found entities: [('Automating Access Control Logics', 'Process/Task', 'The process of translating and embedding access control logics into simple type theory using a theorem prover.'), ('LEO-II', 'Tool/Software', 'A higher-order automated theorem prover used for reasoning in and about normal multimodal and monomodal logics.'), ('Simple Type Theory', 'Formal System', 'A formal system that includes simple type theory, also known as higher-order logic.'), ('Modal Logic S4', 'Formal System', 'A normal modal logic system used for the translation of access control logics.'), ('Garg and Abadi', 'Researchers/Experts', 'The researchers who proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.'), ('Normal Multimodal Logics', 'Formal System', 'A collection of multimodal logics, including monomodal systems K and S4.')]
# Found relationships: [('Automating Access Control Logics', 'LEO-II', 'Utilized by', 'The process of automating access control logics is utilizing the theorem prover LEO-II.'), ('Automating Access Control Logics', 'Simple Type Theory', 'Embedded in', 'The process of automating access control logics involves embedding different access control logics into simple type theory.'), ('LEO-II', 'Modal Logic S4', 'Can automate reasoning about', 'The theorem prover LEO-II can be applied to automate reasoning in modal logic S4.'), ('Garg and Abadi', 'Modal Logic S4', 'Proved sound and complete translation into', 'The researchers Garg and Abadi proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.'), ('Normal Multimodal Logics', 'Simple Type Theory', 'Embedded in', 'Normal multimodal logics, including monomodal systems K and S4, can be embedded in simple type theory.')]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# Generating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.93it/s]

# %%
index.property_graph_store.get_triplets()

# for triplet in index.property_graph_store.get_triplets():
#     print(triplet.re)
# Out:
# [[EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='DEFINED_ON', source_id='Graphical Model', target_id='arbitrary graphical model', properties={'type': 'graph', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'arbitrary graphical model', 'type': 'arbitrary', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='arbitrary graphical model')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='SOLVED_EXACTLY_AND_EFFICIENTLY', source_id='Graphical Model', target_id='tree (graph without loops)', properties={'method': 'BP algorithm', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='GRAPHICAL_STRUCTURE', embedding=None, properties={'id': 'tree (graph without loops)', 'type': 'tree', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='tree (graph without loops)')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='MAY_SHOW_MULTIPLE_MINIMA', source_id='Graphical Model', target_id='Bethe free energy functional', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='FUNCTIONAL', embedding=None, properties={'id': 'Bethe free energy functional', 'type': 'Bethe', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Bethe free energy functional')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='MAY_CONVERGE_INCOMPLETELY', source_id='Graphical Model', target_id='zero-temperature limit', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='TEMPERATURE_STATE', embedding=None, properties={'id': 'zero-temperature limit', 'type': 'zero', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='zero-temperature limit')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='DOES_NOT_GUARANTEE_GLOBAL_MINIMUM', source_id='Graphical Model', target_id='ML solution in the zero-temperature limit', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='SOLUTION', embedding=None, properties={'id': 'ML solution in the zero-temperature limit', 'type': 'Maximum-Likelihood', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='ML solution in the zero-temperature limit')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='HAS_EXCEPTIONS', source_id='Graphical Model', target_id='zero-temperature version of the BP algorithm finds ML solution', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='EXCEPTION', embedding=None, properties={'id': 'zero-temperature version of the BP algorithm finds ML solution', 'type': 'finds', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='zero-temperature version of the BP algorithm finds ML solution')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='SHARES_KEY_FEATURE', source_id='Graphical Model', target_id='two models discussed in \\u003Ccite\\u003E05KW\\u003C/cite\\u003E and \\u003Ccite\\u003E08BSS\\u003C/cite\\u003E', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='MODEL', embedding=None, properties={'id': 'two models discussed in \\u003Ccite\\u003E05KW\\u003C/cite\\u003E and \\u003Ccite\\u003E08BSS\\u003C/cite\\u003E', 'reference': ['<cite>05KW</cite>', '<cite>08BSS</cite>'], 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='two models discussed in \\u003Ccite\\u003E05KW\\u003C/cite\\u003E and \\u003Ccite\\u003E08BSS\\u003C/cite\\u003E')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='CONSIDERED', source_id='Graphical Model', target_id='g-BP algorithm', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='ALGORITHM', embedding=None, properties={'id': 'g-BP algorithm', 'type': 'gedanken', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='g-BP algorithm')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Related To', source_id='Graphical Model', target_id='Zero-Temperature Version of BP Algorithm', properties={'triplet_source_id': 'f7a56b85-42f1-44f0-b455-f025ca642a3f', 'relationship_description': 'Both are related in that zero-temperature versions of algorithms like Belief Propagation can be used to solve specific graphical models.'}),
#   EntityNode(label='Concept/Algorithm', embedding=None, properties={'id': 'Zero-Temperature Version of BP Algorithm', 'entity_description': 'A special case of the Belief Propagation algorithm used at zero temperature, which finds Maximum-Likelihood (ML', 'triplet_source_id': 'f7a56b85-42f1-44f0-b455-f025ca642a3f'}, name='Zero-Temperature Version of BP Algorithm')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Solvable By', source_id='Graphical Model', target_id='Linear Programming', properties={'triplet_source_id': 'f7a56b85-42f1-44f0-b455-f025ca642a3f', 'relationship_description': 'Certain graphical models reducible to Linear Programming with TUM constraints can be solved using the method of Linear Programming.'}),
#   EntityNode(label='Concept/Algorithm', embedding=None, properties={'id': 'Linear Programming', 'entity_description': 'A mathematical optimization technique that can be applied to solve certain classes of problems where the constraints are linear. In this context, it is used alongside TUM matrices for solving graphical models.', 'triplet_source_id': 'f7a56b85-42f1-44f0-b455-f025ca642a3f'}, name='Linear Programming')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Solved by', source_id='Graphical Model', target_id='Iterative Belief Propagation (BP)', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.'}),
#   EntityNode(label='Algorithm', embedding=None, properties={'id': 'Iterative Belief Propagation (BP)', 'entity_description': 'An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Iterative Belief Propagation (BP)')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Minimized by', source_id='Graphical Model', target_id='Bethe Free Energy Functional', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'In the context of tree-like graphs, the Bethe free energy functional is minimized by iterative BP algorithms.'}),
#   EntityNode(label='Concept/Function', embedding=None, properties={'id': 'Bethe Free Energy Functional', 'entity_description': 'A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Bethe Free Energy Functional')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='ML solution is found by', source_id='Graphical Model', target_id='Maximum-Likelihood (ML) Solution', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'In special cases, the ML solutions can be found using efficient algorithms like Linear Programming for certain graphical models with loops.'}),
#   EntityNode(label='Solution', embedding=None, properties={'id': 'Maximum-Likelihood (ML) Solution', 'entity_description': 'The optimal solution obtained in the zero-temperature limit that maximizes likelihood. It is not guaranteed to be found by BP for loopy graphs but can be found using Linear Programming.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Maximum-Likelihood (ML) Solution')],
#  [EntityNode(label='FUNCTIONAL', embedding=None, properties={'id': 'Bethe free energy functional', 'type': 'Bethe', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Bethe free energy functional'),
#   Relation(label='Relation', source_id='Bethe free energy functional', target_id='Maximum-Likelihood (ML) solution', properties={'triplet_source_id': 'd9bcff81-3dd4-4ea2-9f72-480b47264860', 'relationship_description': 'The Bethe free energy functional can have multiple minima, but at zero temperature limit, its minimum may correspond to ML solution under certain conditions."'}),
#   EntityNode(label='Solution', embedding=None, properties={'id': 'Maximum-Likelihood (ML) solution', 'entity_description': 'The optimal solution for a model at zero-temperature limit, often sought after but not guaranteed by iterative Belief Propagation on loopy graphs.', 'triplet_source_id': 'd9bcff81-3dd4-4ea2-9f72-480b47264860'}, name='Maximum-Likelihood (ML) solution')],
#  [EntityNode(label='ALGORITHM', embedding=None, properties={'id': 'g-BP Algorithm', 'type': 'gedanken', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='g-BP Algorithm'),
#   Relation(label='FUNDS', source_id='g-BP Algorithm', target_id='zero-temperature limit', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='TEMPERATURE_STATE', embedding=None, properties={'id': 'zero-temperature limit', 'type': 'zero', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='zero-temperature limit')],
#  [EntityNode(label='OUTPUT', embedding=None, properties={'id': 'g-BP Algorithm output', 'type': 'solution', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='g-BP Algorithm output'),
#   Relation(label='EQUALS', source_id='g-BP Algorithm output', target_id='limit of zero temperature', properties={'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}),
#   EntityNode(label='LIMIT', embedding=None, properties={'id': 'limit of zero temperature', 'type': 'zero', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='limit of zero temperature')],
#  [EntityNode(label='RESEARCH_TOPIC', embedding=None, properties={'id': 'Grammar-Based Random Walkers', 'prop1': 'area of study', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Grammar-Based Random Walkers'),
#   Relation(label='APPLIES_TO', source_id='Grammar-Based Random Walkers', target_id='Semantic Networks', properties={'prop1': 'context', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='NETWORK', embedding=None, properties={'id': 'Semantic Networks', 'prop1': 'domain', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Semantic Networks')],
#  [EntityNode(label='RESEARCH_TOPIC', embedding=None, properties={'id': 'Grammar-Based Random Walkers', 'prop1': 'area of study', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Grammar-Based Random Walkers'),
#   Relation(label='Influenced by', source_id='Grammar-Based Random Walkers', target_id='User Prescribed Contexts', properties={'triplet_source_id': '3e380706-a177-40c2-b433-5aadb1df8c78', 'relationship_description': 'The grammar of the random walkers is defined based on user-prescribed contexts.'}),
#   EntityNode(label='Concept/Setting', embedding=None, properties={'id': 'User Prescribed Contexts', 'entity_description': 'Context-based rankings or metrics defined by users for determining the central vertices.', 'triplet_source_id': '3e380706-a177-40c2-b433-5aadb1df8c78'}, name='User Prescribed Contexts')],
#  [EntityNode(label='NETWORK', embedding=None, properties={'id': 'Semantic Networks', 'prop1': 'domain', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Semantic Networks'),
#   Relation(label='Determines', source_id='Semantic Networks', target_id='Central Vertices', properties={'triplet_source_id': '3e380706-a177-40c2-b433-5aadb1df8c78', 'relationship_description': 'Central vertices are determined in semantic networks.'}),
#   EntityNode(label='Concept', embedding=None, properties={'id': 'Central Vertices', 'entity_description': 'Vertices that are deemed "central" in a semantic network based on subjective importance of relationships.', 'triplet_source_id': '3e380706-a177-40c2-b433-5aadb1df8c78'}, name='Central Vertices')],
#  [EntityNode(label='NETWORK', embedding=None, properties={'id': 'Semantic networks', 'prop1': 'domain', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Semantic networks'),
#   Relation(label='QUALIFIES_MEANING_OF', source_id='Semantic networks', target_id='edge', properties={'prop1': 'action', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='EDGE', embedding=None, properties={'id': 'edge', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='edge')],
#  [EntityNode(label='EDGE', embedding=None, properties={'id': 'edge', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='edge'),
#   Relation(label='RELATES', source_id='edge', target_id='two vertices', properties={'prop1': 'action', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='VERTEX', embedding=None, properties={'id': 'two vertices', 'prop1': 'number', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='two vertices')],
#  [EntityNode(label='QUESTION', embedding=None, properties={'id': 'which vertices are most  central ', 'prop1': 'question', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='which vertices are most "central"'),
#   Relation(label='IS_DIFFICULT_TO_DETERMINE', source_id='which vertices are most "central"', target_id='in a semantic network', properties={'prop1': 'state', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='NETWORK', embedding=None, properties={'id': 'in a semantic network', 'prop1': 'domain', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='in a semantic network')],
#  [EntityNode(label='RELATIONSHIP', embedding=None, properties={'id': 'one relationship type', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='one relationship type'),
#   Relation(label='MAY_BE_DEEMED', source_id='one relationship type', target_id='subjectively more important', properties={'prop1': 'state', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='STATE', embedding=None, properties={'id': 'subjectively more important', 'prop1': 'description', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='subjectively more important')],
#  [EntityNode(label='RESEARCH', embedding=None, properties={'id': 'research into semantic network metrics', 'prop1': 'focus', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='research into semantic network metrics'),
#   Relation(label='HAS_FOCUSED_PRIMARILY_ON', source_id='research into semantic network metrics', target_id='context-based rankings', properties={'prop1': 'area', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='RANKING', embedding=None, properties={'id': 'context-based rankings', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='context-based rankings')],
#  [EntityNode(label='RANKING', embedding=None, properties={'id': 'context-based rankings', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='context-based rankings'),
#   Relation(label='I.E.', source_id='context-based rankings', target_id='user prescribed contexts', properties={'prop1': 'represents', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='CONTEXT', embedding=None, properties={'id': 'user prescribed contexts', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='user prescribed contexts')],
#  [EntityNode(label='METRIC', embedding=None, properties={'id': 'many of the current semantic network metrics', 'prop1': 'category', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='many of the current semantic network metrics'),
#   Relation(label='RANK', source_id='many of the current semantic network metrics', target_id='semantic associations', properties={'prop1': 'action', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='ASSOCIATION', embedding=None, properties={'id': 'semantic associations', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='semantic associations')],
#  [EntityNode(label='ASSOCIATION', embedding=None, properties={'id': 'semantic associations', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='semantic associations'),
#   Relation(label='REPRESENTED_BY', source_id='semantic associations', target_id='directed paths between two vertices', properties={'prop1': 'represents', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='PATH', embedding=None, properties={'id': 'directed paths between two vertices', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='directed paths between two vertices')],
#  [EntityNode(label='CONCEPT', embedding=None, properties={'id': 'Random walkers, in the context of this article', 'prop1': 'context', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Random walkers, in the context of this article'),
#   Relation(label='ARE_CONSTRAINED_BY', source_id='Random walkers, in the context of this article', target_id='a grammar', properties={'prop1': 'condition', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='DATA_STRUCTURE', embedding=None, properties={'id': 'a grammar', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='a grammar')],
#  [EntityNode(label='DATA_STRUCTURE', embedding=None, properties={'id': 'a grammar', 'prop1': 'type', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='a grammar'),
#   Relation(label='DETERMINES_THE', source_id='a grammar', target_id='meaning of the final vertex ranking', properties={'prop1': 'action', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='RANKING', embedding=None, properties={'id': 'meaning of the final vertex ranking', 'prop1': 'output', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='meaning of the final vertex ranking')],
#  [EntityNode(label='STANDARD', embedding=None, properties={'id': 'Resource Description Framework (RDF)', 'prop1': 'name', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='Resource Description Framework (RDF)'),
#   Relation(label='OF', source_id='Resource Description Framework (RDF)', target_id='the Semantic Web initiative', properties={'prop1': 'connection', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}),
#   EntityNode(label='INITIATIVE', embedding=None, properties={'id': 'the Semantic Web initiative', 'prop1': 'group', 'triplet_source_id': 'd753649c-ab98-44b9-a6eb-3e91d4bf9dd9'}, name='the Semantic Web initiative')],
#  [EntityNode(label='ARTICLE_TITLE', embedding=None, properties={'id': 'Faster and better', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='Faster and better'),
#   Relation(label='DISCUSSES', source_id='Faster and better', target_id='machine learning approach to corner detection', properties={'discussion_topic': ['machine learning approach to corner detection'], 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='RESEARCH_TOPIC', embedding=None, properties={'id': 'machine learning approach to corner detection', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='machine learning approach to corner detection')],
#  [EntityNode(label='CORNER_DETECTOR_PROPERTIES', embedding=None, properties={'id': 'repeatability and efficiency', 'importance': 'real-world application', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='repeatability and efficiency'),
#   Relation(label='AFFECTS', source_id='repeatability and efficiency', target_id='usefulness of a corner detector', properties={'impact': 'usefulness', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='UTILITY', embedding=None, properties={'id': 'usefulness of a corner detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='usefulness of a corner detector')],
#  [EntityNode(label='SCENE', embedding=None, properties={'id': 'same scene viewed from different positions', 'viewing_position': 'different', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='same scene viewed from different positions'),
#   Relation(label='SHOULD YIELD', source_id='same scene viewed from different positions', target_id='features which correspond to the same real-world 3D locations', properties={'correspondence': 'real-world 3D locations', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='FEATURES', embedding=None, properties={'id': 'features which correspond to the same real-world 3D locations', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='features which correspond to the same real-world 3D locations')],
#  [EntityNode(label='REFERENCE', embedding=None, properties={'id': 'Schmid et al 2000', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='Schmid et al 2000'),
#   Relation(label='CITES', source_id='Schmid et al 2000', target_id='repeatability criterion', properties={'work': 'repeatability criterion', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='CRITERION', embedding=None, properties={'id': 'repeatability criterion', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='repeatability criterion')],
#  [EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'Harris detector', 'processing_time': '115%', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='Harris detector'),
#   Relation(label='CANNOT OPERATE AT FRAME RATE', source_id='Harris detector', target_id='frame rate', properties={'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='OPERATIONAL_SPEED', embedding=None, properties={'id': 'frame rate', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='frame rate')],
#  [EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'SIFT', 'processing_time': '195%', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='SIFT'),
#   Relation(label='CANNOT OPERATE AT FRAME RATE', source_id='SIFT', target_id='frame rate', properties={'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='OPERATIONAL_SPEED', embedding=None, properties={'id': 'frame rate', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='frame rate')],
#  [EntityNode(label='HEURISTIC', embedding=None, properties={'id': 'new heuristic for feature detection', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='new heuristic for feature detection'),
#   Relation(label='PRESENTED', source_id='new heuristic for feature detection', target_id='live PAL video processing', properties={'purpose': 'live PAL video processing', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='APPLICATION', embedding=None, properties={'id': 'live PAL video processing', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='live PAL video processing')],
#  [EntityNode(label='TECHNIQUE', embedding=None, properties={'id': 'machine learning', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='machine learning'),
#   Relation(label='DERIVES', source_id='machine learning', target_id='feature detector', properties={'derivative': 'feature detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='DETECTOR', embedding=None, properties={'id': 'feature detector', 'processing_time': '< 5%', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='feature detector')],
#  [EntityNode(label='TECHNIQUE', embedding=None, properties={'id': 'machine learning', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='machine learning'),
#   Relation(label='improves', source_id='machine learning', target_id='Harris detector', properties={'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e', 'relationship_description': 'The use of machine learning improved the performance of the Harris detector by making it more efficient while maintaining or slightly degrading its repeatability.'}),
#   EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'Harris detector', 'processing_time': '115%', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='Harris detector')],
#  [EntityNode(label='TECHNIQUE', embedding=None, properties={'id': 'machine learning', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='machine learning'),
#   Relation(label='improves', source_id='machine learning', target_id='SIFT (Scale-Invariant Feature Transform)', properties={'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e', 'relationship_description': 'The use of machine learning improved the performance of SIFT by making it more efficient while maintaining or slightly degrading its repeatability.'}),
#   EntityNode(label='Existing Algorithm', embedding=None, properties={'id': 'SIFT (Scale-Invariant Feature Transform)', 'entity_description': 'Another popular feature detection and description method mentioned for comparative analysis.', 'triplet_source_id': 'ac79cf0a-e12c-4c0f-ba43-1e48fdf62ba3'}, name='SIFT (Scale-Invariant Feature Transform)')],
#  [EntityNode(label='CORNER_DETECTOR_PROPERTIES', embedding=None, properties={'id': 'efficiency', 'importance': 'operate at frame rate', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='efficiency'),
#   Relation(label='AFFECTS', source_id='efficiency', target_id='ability to operate at frame rate', properties={'impact': 'combined with further processing', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='OPERATIONAL_SPEED', embedding=None, properties={'id': 'ability to operate at frame rate', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='ability to operate at frame rate')],
#  [EntityNode(label='CORNER_DETECTOR_FEATURE', embedding=None, properties={'id': 'optimization for repeatability', 'optimization_type': 'repeatability', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='optimization for repeatability'),
#   Relation(label='ALLOWED', source_id='optimization for repeatability', target_id='corner detector', properties={'loss': 'little', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'corner detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='corner detector')],
#  [EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'corner detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='corner detector'),
#   Relation(label='requires', source_id='corner detector', target_id='efficiency', properties={'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e', 'relationship_description': 'The corner detector needs to be efficient so that it can operate in real-time applications.'}),
#   EntityNode(label='CORNER_DETECTOR_PROPERTIES', embedding=None, properties={'id': 'efficiency', 'importance': 'operate at frame rate', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='efficiency')],
#  [EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'corner detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='corner detector'),
#   Relation(label='requires', source_id='corner detector', target_id='repeatability', properties={'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e', 'relationship_description': 'The corner detector must have high repeatability to ensure consistent feature detection across different viewpoints.'}),
#   EntityNode(label='quality attribute', embedding=None, properties={'id': 'repeatability', 'entity_description': 'The property of a corner detector that ensures the same scene viewed from different positions will produce corresponding features.', 'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e'}, name='repeatability')],
#  [EntityNode(label='CORNER_DETECTOR', embedding=None, properties={'id': 'corner detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='corner detector'),
#   Relation(label='can fully process', source_id='corner detector', target_id='live PAL video processing', properties={'triplet_source_id': '5ffac5a5-cdc5-4b5e-95c6-e548bdb81a4e', 'relationship_description': 'The new corner detector can fully process live PAL video."'}),
#   EntityNode(label='APPLICATION', embedding=None, properties={'id': 'live PAL video processing', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='live PAL video processing')],
#  [EntityNode(label='SCENE', embedding=None, properties={'id': '3D scenes', 'dimension': '3D', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='3D scenes'),
#   Relation(label='USED FOR', source_id='3D scenes', target_id='comparison of corner detectors', properties={'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='COMPARISON', embedding=None, properties={'id': 'comparison of corner detectors', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='comparison of corner detectors')],
#  [EntityNode(label='DETECTOR', embedding=None, properties={'id': 'our heuristic detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='our heuristic detector'),
#   Relation(label='OUTPERFORMS', source_id='our heuristic detector', target_id='existing feature detectors', properties={'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd', 'existing_detectors': True}),
#   EntityNode(label='FEATURE_DETECTOR', embedding=None, properties={'id': 'existing feature detectors', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='existing feature detectors')],
#  [EntityNode(label='TESTS', embedding=None, properties={'id': 'stringent tests', 'criterion': 'repeatability', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='stringent tests'),
#   Relation(label='APPLIED TO', source_id='stringent tests', target_id='3D scenes', properties={'scene': '3D scenes', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='SCENE', embedding=None, properties={'id': '3D scenes', 'dimension': '3D', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='3D scenes')],
#  [EntityNode(label='TECHNIQUE_USE', embedding=None, properties={'id': 'using machine learning', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='using machine learning'),
#   Relation(label='PRODUCES', source_id='using machine learning', target_id='significant improvements in repeatability', properties={'improvement': 'repeatability', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='IMPROVEMENT', embedding=None, properties={'id': 'significant improvements in repeatability', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='significant improvements in repeatability')],
#  [EntityNode(label='DETECTOR', embedding=None, properties={'id': 'very fast and very high quality', 'speed': 'fast', 'quality': 'high', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='very fast and very high quality'),
#   Relation(label='RESULTS IN', source_id='very fast and very high quality', target_id='our heuristic detector', properties={'detector': 'our heuristic detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}),
#   EntityNode(label='DETECTOR', embedding=None, properties={'id': 'our heuristic detector', 'triplet_source_id': '1198ae08-be4e-4c1d-811b-06b1c213f7cd'}, name='our heuristic detector')],
#  [EntityNode(label='PROFESSION', embedding=None, properties={'id': 'AI researchers', 'argues': ['analogy is the core of cognition'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='AI researchers'),
#   Relation(label='ARGUE', source_id='AI researchers', target_id='analogy', properties={'about': ['the core of cognition'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='CONCEPT', embedding=None, properties={'id': 'analogy', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='analogy')],
#  [EntityNode(label='THEORY', embedding=None, properties={'id': 'Structure Mapping Theory (SMT)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Structure Mapping Theory (SMT)'),
#   Relation(label='IMPLEMENTED', source_id='Structure Mapping Theory (SMT)', target_id='Structure Mapping Engine (SME)', properties={'in': ['the Structure Mapping Engine (SME)'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Structure Mapping Engine (SME)', 'limitation': ['requirement for complex hand-coded representations'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Structure Mapping Engine (SME)')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Structure Mapping Engine (SME)', 'limitation': ['requirement for complex hand-coded representations'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Structure Mapping Engine (SME)'),
#   Relation(label='INTRODUCED', source_id='Structure Mapping Engine (SME)', target_id='Latent Relation Mapping Engine (LRME)', properties={'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='COMBINES', source_id='Latent Relation Mapping Engine (LRME)', target_id='SME and LRA', properties={'ideas': ['from SME and Latent Relational Analysis (LRA)'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='CONCEPTS', embedding=None, properties={'id': 'SME and LRA', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='SME and LRA')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='REMOVES_REQUIREMENT', source_id='Latent Relation Mapping Engine (LRME)', target_id='requirement for hand-coded representations', properties={'for': ['hand-coded representations'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='SYSTEM_LIMITATION', embedding=None, properties={'id': 'requirement for hand-coded representations', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='requirement for hand-coded representations')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='BUILDs', source_id='Latent Relation Mapping Engine (LRME)', target_id='lists of words', properties={'analogical mappings': ['between lists of words'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='DATASET', embedding=None, properties={'id': 'lists of words', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='lists of words')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='USES', source_id='Latent Relation Mapping Engine (LRME)', target_id='raw text', properties={'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304', 'a large corpus of raw text': ['to automatically discover the semantic relations among the words']}),
#   EntityNode(label='DATASET', embedding=None, properties={'id': 'raw text', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='raw text')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='EVALUATED_ON', source_id='Latent Relation Mapping Engine (LRME)', target_id='twenty analogical mapping problems', properties={'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='DATASET', embedding=None, properties={'id': 'twenty analogical mapping problems', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='twenty analogical mapping problems')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='ACHIEVES', source_id='Latent Relation Mapping Engine (LRME)', target_id='human-level performance', properties={'human-level performance': ['on the twenty problems'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='PERFORMANCE_LEVEL', embedding=None, properties={'id': 'human-level performance', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='human-level performance')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='Influenced By', source_id='Latent Relation Mapping Engine (LRME)', target_id='Structure Mapping Theory (SMT)', properties={'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133', 'relationship_description': 'The LRME builds on the concept of structure mapping, aiming to improve upon SME by removing the need for hand-coded representations."'}),
#   EntityNode(label='THEORY', embedding=None, properties={'id': 'Structure Mapping Theory (SMT)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Structure Mapping Theory (SMT)')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='Inspired From', source_id='Latent Relation Mapping Engine (LRME)', target_id='Structure Mapping Engine (SME)', properties={'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133', 'relationship_description': 'The LRME is inspired by the Structure Mapping Engine but improves its limitations in requiring complex hand-coded representations."'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Structure Mapping Engine (SME)', 'limitation': ['requirement for complex hand-coded representations'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Structure Mapping Engine (SME)')],
#  [EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)'),
#   Relation(label='Combined With', source_id='Latent Relation Mapping Engine (LRME)', target_id='Latent Relational Analysis (LRA)', properties={'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133', 'relationship_description': 'Both LRA and SME ideas are combined to create the LRME, aiming to discover semantic relations automatically without manual coding."'}),
#   EntityNode(label='Analysis Technique', embedding=None, properties={'id': 'Latent Relational Analysis (LRA)', 'entity_description': 'A technique used in LRME to automatically discover semantic relations among words using a large corpus of raw text.', 'triplet_source_id': '7379e121-fab4-4b07-b318-fd7fd0e6dd73'}, name='Latent Relational Analysis (LRA)')],
#  [EntityNode(label='APPROACH', embedding=None, properties={'id': 'Various alternative approaches', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Various alternative approaches'),
#   Relation(label='COMPARED_WITH', source_id='Various alternative approaches', target_id='LRME', properties={'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'LRME', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='LRME')],
#  [EntityNode(label='APPROACH', embedding=None, properties={'id': 'Various alternative approaches', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Various alternative approaches'),
#   Relation(label='NOT_ABLE', source_id='Various alternative approaches', target_id='same level of performance', properties={'to reach the same level of performance': ['as LRME'], 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}),
#   EntityNode(label='PERFORMANCE_LEVEL', embedding=None, properties={'id': 'same level of performance', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='same level of performance')],
#  [EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II'),
#   Relation(label='can automate reasoning in and about', source_id='LEO-II', target_id='monomodal logics K and S4', properties={'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}),
#   EntityNode(label='LOGIC', embedding=None, properties={'id': 'monomodal logics K and S4', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='monomodal logics K and S4')],
#  [EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II'),
#   Relation(label='can also automate reasoning in and about', source_id='LEO-II', target_id='different access control logics', properties={'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}),
#   EntityNode(label='ACCESS_CONTROL_LOGIC', embedding=None, properties={'id': 'different access control logics', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='different access control logics')],
#  [EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II'),
#   Relation(label='can be applied to automate reasoning in', source_id='LEO-II', target_id='prominent access control logics', properties={'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}),
#   EntityNode(label='ACCESS_CONTROL_LOGIC', embedding=None, properties={'id': 'prominent access control logics', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='prominent access control logics')],
#  [EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II'),
#   Relation(label='Automation', source_id='LEO-II', target_id='Reasoning in Access Control Logics', properties={'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36', 'relationship_description': 'LEO-II can automate the reasoning process in access control logics when embedded in simple type theory.'}),
#   EntityNode(label='Task', embedding=None, properties={'id': 'Reasoning in Access Control Logics', 'entity_description': 'The process of applying logical reasoning to access control systems.', 'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36'}, name='Reasoning in Access Control Logics')],
#  [EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II'),
#   Relation(label='Can automate reasoning about', source_id='LEO-II', target_id='Modal Logic S4', properties={'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce', 'relationship_description': 'The theorem prover LEO-II can be applied to automate reasoning in modal logic S4.'}),
#   EntityNode(label='Logical System', embedding=None, properties={'id': 'Modal Logic S4', 'entity_description': 'A modal logic system used to translate certain access control logics, characterized by its properties such as necessity and possibility.', 'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36'}, name='Modal Logic S4')],
#  [EntityNode(label='ACCESS_CONTROL_LOGIC', embedding=None, properties={'id': 'Different Access Control Logics', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='Different Access Control Logics'),
#   Relation(label='can be embedded in', source_id='Different Access Control Logics', target_id='Simple Type Theory', properties={'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}),
#   EntityNode(label='LOGIC', embedding=None, properties={'id': 'Simple Type Theory', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='Simple Type Theory')],
# ...
#  [EntityNode(label='Software Tool', embedding=None, properties={'id': 'Theorem Prover LEO-II', 'entity_description': 'A higher-order automated theorem prover that can be used for reasoning in simple type theory and its embedding of modal logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Theorem Prover LEO-II'),
#   Relation(label='Application', source_id='Theorem Prover LEO-II', target_id='Automated Access Control Reasoning', properties={'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5', 'relationship_description': 'LEO-II is applied to automate reasoning in prominent access control logics.'}),
#   EntityNode(label='Concept/Process', embedding=None, properties={'id': 'Automated Access Control Reasoning', 'entity_description': 'The process of using automated theorem provers to reason about and validate the correctness of access control policies/logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Automated Access Control Reasoning')],
#  [EntityNode(label='Algorithm', embedding=None, properties={'id': 'Iterative Belief Propagation (BP)', 'entity_description': 'An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Iterative Belief Propagation (BP)'),
#   Relation(label='Converges to minimum of', source_id='Iterative Belief Propagation (BP)', target_id='Bethe Free Energy Functional', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'For loopy graphical models, the iterative BP algorithm may converge to one of multiple minima or not converge at all.'}),
#   EntityNode(label='Concept/Function', embedding=None, properties={'id': 'Bethe Free Energy Functional', 'entity_description': 'A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Bethe Free Energy Functional')],
#  [EntityNode(label='Algorithm', embedding=None, properties={'id': 'Linear Programming (LP)', 'entity_description': 'A method used to find the global minimum of a function subject to constraints, specifically applicable in finding ML solutions and equivalent to certain forms of graphical models in the zero-temperature limit.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Linear Programming (LP)'),
#   Relation(label='Reducible to in zero-temperature limit', source_id='Linear Programming (LP)', target_id='Graphical Model', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'A class of graphical models is reducible in the zero-temperature limit to LP with TUM constraints.'}),
#   EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model')],
#  [EntityNode(label='Problem Set', embedding=None, properties={'id': 'Analogical Mapping Problems', 'entity_description': 'A set of problems used to evaluate the performance of different analogy-making algorithms, consisting of ten scientific analogies and ten common metaphors based ones."', 'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133'}, name='Analogical Mapping Problems'),
#   Relation(label='Evaluated By', source_id='Analogical Mapping Problems', target_id='Latent Relation Mapping Engine (LRME)', properties={'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133', 'relationship_description': 'The LRME is evaluated on a set of analogical mapping problems designed to test its performance against other methods."'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)')],
#  [EntityNode(label='(Attribute)', embedding=None, properties={'id': 'Performance', 'entity_description': 'Measure of how well an algorithm or system performs in a specific task.', 'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133'}, name='Performance'),
#   Relation(label='Measured By', source_id='Performance', target_id='Latent Relation Mapping Engine (LRME)', properties={'triplet_source_id': 'c541f63a-d348-4290-9f20-0486ed1ac133', 'relationship_description': 'The performance of the LRME is measured using the set of analogical mapping problems, showing human-level accuracy.'}),
#   EntityNode(label='SYSTEM', embedding=None, properties={'id': 'Latent Relation Mapping Engine (LRME)', 'triplet_source_id': '832af341-594b-451c-8a36-e55b4e76e304'}, name='Latent Relation Mapping Engine (LRME)')],
#  [EntityNode(label='Process/Task', embedding=None, properties={'id': 'Automating Access Control Logics', 'entity_description': 'The process of translating and embedding access control logics into simple type theory using a theorem prover.', 'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce'}, name='Automating Access Control Logics'),
#   Relation(label='Utilized by', source_id='Automating Access Control Logics', target_id='LEO-II', properties={'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce', 'relationship_description': 'The process of automating access control logics is utilizing the theorem prover LEO-II.'}),
#   EntityNode(label='TOOL', embedding=None, properties={'id': 'LEO-II', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='LEO-II')],
#  [EntityNode(label='Process/Task', embedding=None, properties={'id': 'Automating Access Control Logics', 'entity_description': 'The process of translating and embedding access control logics into simple type theory using a theorem prover.', 'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce'}, name='Automating Access Control Logics'),
#   Relation(label='Embedded in', source_id='Automating Access Control Logics', target_id='Simple Type Theory', properties={'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce', 'relationship_description': 'The process of automating access control logics involves embedding different access control logics into simple type theory.'}),
#   EntityNode(label='LOGIC', embedding=None, properties={'id': 'Simple Type Theory', 'triplet_source_id': 'f7d9b6e4-c572-4110-b73a-8b5765a533ba'}, name='Simple Type Theory')],
#  [EntityNode(label='Researchers/Experts', embedding=None, properties={'id': 'Garg and Abadi', 'entity_description': 'The researchers who proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.', 'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce'}, name='Garg and Abadi'),
#   Relation(label='Proved sound and complete translation into', source_id='Garg and Abadi', target_id='Modal Logic S4', properties={'triplet_source_id': '1bd6c373-9fae-4fd2-a291-f2d7902f56ce', 'relationship_description': 'The researchers Garg and Abadi proved that prominent access control logics can be translated in a sound and complete way into modal logic S4.'}),
#   EntityNode(label='Logical System', embedding=None, properties={'id': 'Modal Logic S4', 'entity_description': 'A modal logic system used to translate certain access control logics, characterized by its properties such as necessity and possibility.', 'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36'}, name='Modal Logic S4')],
#  [EntityNode(label='Algorithm and Experiments', embedding=None, properties={'id': 'Latent Relation Mapping Engine', 'entity_description': 'The Latent Relation Mapping Engine is an AI model that combines ideas from Structure Mapping Theory and Latent Relational Analysis to automatically discover semantic relations among words, aiming to remove the need for hand-coded representations.', 'triplet_source_id': '7379e121-fab4-4b07-b318-fd7fd0e6dd73'}, name='Latent Relation Mapping Engine'),
#   Relation(label='Evaluates On', source_id='Latent Relation Mapping Engine', target_id='Analogical mapping problems', properties={'triplet_source_id': 'be680546-5f3f-435e-9dae-268b40a5ac89', 'relationship_description': 'LRME is tested on a set of twenty analogical mapping tasks designed to assess its performance in creating mappings between words, both scientific and metaphorical in nature.'}),
#   EntityNode(label='Problem Set', embedding=None, properties={'id': 'Analogical mapping problems', 'entity_description': 'Sets of twenty analogical mapping tasks used to evaluate LRME and other approaches, including both scientific analogies and common metaphors.', 'triplet_source_id': 'be680546-5f3f-435e-9dae-268b40a5ac89'}, name='Analogical mapping problems')],
#  [EntityNode(label='Software Tool', embedding=None, properties={'id': 'Theorem Prover LEO-II', 'entity_description': 'A higher-order automated theorem prover that can be used for reasoning in simple type theory and its embedding of modal logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Theorem Prover LEO-II'),
#   Relation(label='Application', source_id='Theorem Prover LEO-II', target_id='Automated Access Control Reasoning', properties={'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5', 'relationship_description': 'LEO-II is applied to automate reasoning in prominent access control logics.'}),
#   EntityNode(label='Concept/Process', embedding=None, properties={'id': 'Automated Access Control Reasoning', 'entity_description': 'The process of using automated theorem provers to reason about and validate the correctness of access control policies/logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Automated Access Control Reasoning')],
#  [EntityNode(label='Person', embedding=None, properties={'id': 'Garg', 'entity_description': 'A person involved in recent research on access control logics."', 'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36'}, name='Garg'),
#   Relation(label='Usage', source_id='Garg', target_id='Theorem Prover LEO-II', properties={'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5', 'relationship_description': 'Garg used the theorem prover to automate reasoning in and about different access control logics.'}),
#   EntityNode(label='Software Tool', embedding=None, properties={'id': 'Theorem Prover LEO-II', 'entity_description': 'A higher-order automated theorem prover that can be used for reasoning in simple type theory and its embedding of modal logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Theorem Prover LEO-II')],
#  [EntityNode(label='Person', embedding=None, properties={'id': 'Abadi', 'entity_description': 'A person involved in recent research on access control logics."', 'triplet_source_id': 'a055bff2-6b8b-492c-886a-1b9043437c36'}, name='Abadi'),
#   Relation(label='Usage', source_id='Abadi', target_id='Theorem Prover LEO-II', properties={'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5', 'relationship_description': 'Abadi used the theorem prover to validate their translation of access control logics into modal logic S4.'}),
#   EntityNode(label='Software Tool', embedding=None, properties={'id': 'Theorem Prover LEO-II', 'entity_description': 'A higher-order automated theorem prover that can be used for reasoning in simple type theory and its embedding of modal logics.', 'triplet_source_id': 'd4bd6f6a-1409-4181-aa4a-ccd25decd2f5'}, name='Theorem Prover LEO-II')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Solved by', source_id='Graphical Model', target_id='Iterative Belief Propagation (BP)', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.'}),
#   EntityNode(label='Algorithm', embedding=None, properties={'id': 'Iterative Belief Propagation (BP)', 'entity_description': 'An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Iterative Belief Propagation (BP)')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='Minimized by', source_id='Graphical Model', target_id='Bethe Free Energy Functional', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'In the context of tree-like graphs, the Bethe free energy functional is minimized by iterative BP algorithms.'}),
#   EntityNode(label='Concept/Function', embedding=None, properties={'id': 'Bethe Free Energy Functional', 'entity_description': 'A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Bethe Free Energy Functional')],
#  [EntityNode(label='Algorithm', embedding=None, properties={'id': 'Iterative Belief Propagation (BP)', 'entity_description': 'An iterative algorithm used in solving graphical models defined on tree-like graphs. It converges to a unique minimum of the Bethe free energy functional, but for loopy graphs, it may converge to one of multiple minima or not converge at all.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Iterative Belief Propagation (BP)'),
#   Relation(label='Converges to minimum of', source_id='Iterative Belief Propagation (BP)', target_id='Bethe Free Energy Functional', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'For loopy graphical models, the iterative BP algorithm may converge to one of multiple minima or not converge at all.'}),
#   EntityNode(label='Concept/Function', embedding=None, properties={'id': 'Bethe Free Energy Functional', 'entity_description': 'A function used in statistical inference that is minimized by iterative BP algorithms on tree-like graphical models. For loopy graphs, it can have multiple minima.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Bethe Free Energy Functional')],
#  [EntityNode(label='STATISTICAL_MODEL', embedding=None, properties={'id': 'Graphical Model', 'type': 'reducible LP with TUM constraints', 'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}, name='Graphical Model'),
#   Relation(label='ML solution is found by', source_id='Graphical Model', target_id='Maximum-Likelihood (ML) Solution', properties={'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def', 'relationship_description': 'In special cases, the ML solutions can be found using efficient algorithms like Linear Programming for certain graphical models with loops.'}),
#   EntityNode(label='Solution', embedding=None, properties={'id': 'Maximum-Likelihood (ML) Solution', 'entity_description': 'The optimal solution obtained in the zero-temperature limit that maximizes likelihood. It is not guaranteed to be found by BP for loopy graphs but can be found using Linear Programming.', 'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def'}, name='Maximum-Likelihood (ML) Solution')]]

# %%
index.property_graph_store.get_triplets()[10][0].properties
# Out:
# {'id': 'Graphical Model',
#  'type': 'reducible LP with TUM constraints',
#  'triplet_source_id': 'b2f2dda2-a5e4-4cc9-ae08-a977488d1db4'}

# %%
index.property_graph_store.get_triplets()[10][1].properties
# Out:
# {'triplet_source_id': '5081b3d2-dff5-457d-a7c5-326b659c0def',
#  'relationship_description': 'The iterative BP algorithm is used to solve graphical models defined on tree-like graphs.'}

# %% [markdown]
# ### Build communities
#
# This will create communities and summary for each community.

# %%
index.property_graph_store.build_communities()

# %%
import networkx as nx
from pyvis.network import Network

net = Network(
    directed = True,
    select_menu = True, 
    filter_menu = True, 
)
net.show_buttons() 
net.from_nx(graph_store._create_nx_graph()) 
net.write_html('community_graph.html')

# %% [markdown]
# ### Create QueryEngine

# %%
query_engine = GraphRAGQueryEngine(
    graph_store=index.property_graph_store,
    llm=llm,
    index=index,
    similarity_top_k=10,
)

# %% [markdown]
# ### Querying

# %%
response = query_engine.query(
    "What are the main topics discussed in the papers?"
)
display(Markdown(f"{response.response}"))
# Out:
# The main topics discussed in the papers include:
#
# 1. **Graphical Model Entities and Their Definitions:**
#    - Arbitrary graphical models.
#    - Trees (graphs without loops).
#    - The Bethe free energy functional.
#
# 2. **Solvability and Algorithms:**
#    - Solvability of graphical models at different temperatures, particularly focusing on the Zero-Temperature limit.
#    - Performance of specific algorithms like the Zero-Temperature Version of BP Algorithm.
#    - The g-BP algorithm as a generalized version of BP for finding global minima.
#
# 3. **Convergence and Minimization:**
#    - Convergence behavior of Iterative Belief Propagation (BP) in tree-like and loopy structures.
#    - Minimizing the Bethe free energy functional using iterative BP algorithms on tree-like graphs.
#
# 4. **Interrelationships Between Algorithms and Functionalities:**
#    - Relationship between Belief Propagation and its Zero-Temperature Version for solving specific graphical models.
#    - The role of g-BP algorithm in finding global minima, especially under zero-temperature limits.
#
# 5. **Efficiency and Solvability:**
#    - Efficiency of Iterative BP for tree-like structures.
#    - Challenges with convergence in loopy graphs.
#
# 6. **Convergence Issues and Solutions:**
#    - Convergence issues faced by iterative algorithms like BP in loopy structures.
#    - Effectiveness of Zero-Temperature versions of algorithms and g-BP algorithm in finding global minima under specific conditions.
#
# 7. **Functional Minimization:**
#    - The role of the Bethe free energy functional in minimizing for tree-like structures, often aligning with ML solutions at zero temperature limits.
#
# 8. **Tree-like Graphs and Their Solution Methods:**
#    - Use of Iterative Belief Propagation (BP) for solving tree-like graphs exactly.
#    - Minimization by iterative BP algorithms in tree-like structures, with potential multiple minima.
#
# 9. **Zero-Temperature Limit:**
#    - Convergence and failure modes of the zero-temperature limit of Belief Propagation and certain graphical models.
#    - The process finds Maximum Likelihood (ML) solutions but can fail to converge completely or find global minima in some cases.
#
# 10. **Linear Programming with Transversality Uniqueness Maximization (TUM):**
#     - Application of Linear Programming for solving specific graphical models, particularly those with loops in the zero-temperature limit.
#     - The method provides efficient solutions for certain ML problems.
#
# 11. **Generalized Belief Propagation (g-BP) Algorithm:**
#     - A generalization of the BP algorithm applicable to some specific problems or scenarios.
#
# 12. **Model Specifics and Interconnectedness:**
#     - Two models discussed in [05KW] and [08BSS] share key features, suggesting their interconnectedness in theoretical or practical aspects.
#
# 13. **Interrelated Concepts:**
#     - The relationship between the zero-temperature version of BP algorithms and their application to solving specific graphical models.
#
# Additionally, there is another set of papers that focus on:
#
# 14. **Bethe Free Energy Functional (BFEF):**
#    - Multiple minima explored, particularly at zero temperature where one minimum can align with the Maximum-Likelihood (ML) solution.
#
# 15. **Maximum-Likelihood Solution:**
#    - Connection between BFEF and ML solutions highlighted, noting that while BFEF can have multiple local optima, it converges to the ML solution in the absence of thermal fluctuations or at zero temperature.
#
# 16. **Belief Propagation (BP):**
#    - Role in calculating BFEF on tree structures.
#
# 17. **Generalized Belief Propagation (g-BP) Algorithm:**
#    - Generalization aimed at finding global minima and related to ML solutions under certain conditions.

# %%
response = query_engine.query(
    "Which papers have the most in common?"
)
display(Markdown(f"{response.response}"))
# Out:
# Based on the provided summaries, here are the key findings:
#
# 1. **Papers with Shared Features**:
#    - **05KW** (published around 2005) and **08BSS** (published around 2008) share specific key features related to graphical models and algorithms, focusing on iterative algorithms like BP at zero temperature limits and their relation to finding ML solutions.
#
# 2. **Entities with the Most in Common**:
#    - **LEO-II and Modal Logic S4**: These are directly involved as LEO-II can automate reasoning within modal logic S4.
#    - **Garg and Abadi's Contribution**: Their work involves translating prominent access control logics into modal logic S4, enhancing automated reasoning using LEO-II.
#
# 3. **Papers Focusing on Random Walks and Graph Theory**:
#    - Works that explore random walks through semantic networks defined by user-prescribed grammars.
#    - Utilization of RDF to structure and analyze data in these networks.
#    - Application of centrality metrics like eigenvector centrality and PageRank.
#    - Influence of context-based inputs on traversal paths.
#
# 4. **Latent Relation Mapping Engine (LRME)**:
#    - Evaluation through 20 analogical mapping tasks, focusing on its performance with scientific and metaphorical words.
#
# 5. **Papers Related to Bethe Free Energy Functional (BFEF), Maximum-Likelihood (ML) Solutions, Belief Propagation (BP), and Generalized BP (g-BP)**:
#    - Papers discussing the properties and applications of BFEF.
#    - Studies on ML solutions in graphical models.
#    - Research on BP algorithms and their extensions like g-BP.
#
# 6. **Papers by Garg and Abadi**:
#    - Their work involves translating access control logics into Modal Logic S4, using Simple Type Theory (Higher-Order Logic) to enhance automated reasoning with LEO-II.
#
# 7. **Central Vertices in Semantic Networks**:
#    - Papers focusing on identifying and analyzing central vertices.
#    - Application of PageRank and eigenvector centrality metrics.
#    - Utilization of RDF as a framework for these applications.
#
# Overall, the papers or works that share the most common ground tend to integrate elements like random walks, RDF, centrality metrics, and automated reasoning frameworks.

# %%
response = query_engine.query("What are the main news in energy sector?")
display(Markdown(f"{response.response}"))
# Out:
# It seems there might be a misunderstanding. The provided summaries focus on topics such as graphical models, theorem provers, machine learning techniques, and feature detectors, which are not directly related to the current news in the energy sector.
#
# For main news in the energy sector, I recommend checking recent reports from reputable sources like the International Energy Agency (IEA), Reuters, Bloomberg, or other energy-specific publications. These sources typically cover topics such as:
#
# 1. **Renewable Energy Advancements**: Updates on solar, wind, and other renewable technologies.
# 2. **Fossil Fuel Prices and Policies**: Changes in oil, gas, and coal prices, as well as policy updates affecting these industries.
# 3. **Energy Transition Initiatives**: Government policies, corporate strategies, and technological innovations aimed at reducing carbon emissions.
# 4. **Infrastructure Developments**: New projects related to energy production, transmission, and storage infrastructure.
#
# If you need specific recent news articles or data points, feel free to ask for guidance on where to find them!
